# %% [markdown]
# # 서울특별시 방배동의 요기요 식당 정보
# - 매장명, 평점평균, 리뷰수, 사장님답글수, 최소주문금액 가져오기

# %%
import requests
import pandas as pd
import numpy as np
import os

# %%
url = 'https://www.yogiyo.co.kr/api/v1/restaurants-geo/?items=60&lat=37.4835309976812&lng=126.991938810326&order=rank&page=0&search='
response = requests.get(url)
print(response)  # 400 에러 Bad Request
print(response.text) # 에러의 내용
# Out:
# <Response [400]>
# [["error", "API key or secret is missing"]]

# %%
# 400 에러 가 뜬다
# 접근이 막혀있다.
# 에러메세지는 API key or secret is missing

# %% [markdown]
# 웹크롤러 같은 봇이 함부로 자사의 사이트 정보를 크롤링 하지 못하게 필터링 하는 다양한 방법이 있는데
# 그중에 하나가 request 시 추가 되는 header 정보를 사용하는 방법이다
# 1. header 정보를 통해 정상적인 request 인지 확인하거나
# 2. header 에 특수한 정보를 넣어서 그 정보가 있는 경우에만 정상적으로 response 한다든가

# %%
# API key 와 secret을 찾아서 header 에 추가해보자
# 근데 API key를 어떻게 찾을까????
# 우리에겐 구글 크롬이 있다

# %%
# 그 전에 파이썬으로 request 를 할때 헤더는 어떻게 생겼는지 한번 보도록 하자

py_header = requests.get('https://httpbin.org/headers')  # header를 볼수 있는 url
print(py_header.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-618ba606-5807c8ef4ae3c2fa4715e9c4"
#   }
# }

# %%
# 헤더에 인위적으로 api 키를 추가해서 요기요 서버를 한번 속여보자

# %%
#headers 정보 추가
headers = {
  "X-ApiKey": "iphoneap",  # API key
  "X-ApiSecret": "fe5183cc3dea12bd0ce299cf110a75a2",  # secret
  'User-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36"  # 크롬에서 리퀘스트 한척 하기
}

# %%
response = requests.get(url, headers=headers) # 헤더 정보 수정&추가
print(response)

# ↓↓↓↓ 200 떳따!
# Out:
# <Response [200]>

# %%
# json() 함수로 json 으로 변환하여 새로운 변수에 담는다.
ygy_data =  response.json()
ygy_data
# Out:
# {'pagination': {'per_page': 60,
#   'total_objects': 2371,
#   'current_page': 0,
#   'total_pages': 40},
#  'restaurants': [{'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 1,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.2523366,
#    'app_order': True,
#    'lng': 126.9860396,
#    'list_pos': 1,
#    'open': True,
#    'id': 54915,
#    'estimated_delivery_time': '25~35분',
#    'review_count': 1375,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'superlist',
#    'restaurant_type': 'food',
#    'franchise_id': 82,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181004182813010545_d61c21551fb145915b554bc893ffe4f5_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': '주식회사김가네 / 김가네',
#    'thumbnail_message': '',
#    'begin': '09:30:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.49387,
#    'end': '20:20:00',
#    'discount_until': None,
#    'categories': ['분식', '한식', '프랜차이즈'],
#    'review_avg': 4.6,
#    'min_order_amount': 15000,
#    'distance': 1.26198076014,
#    'minimum_pickup_minutes': 0,
#    'except_cash': False,
#    'name': '김가네-방배본동점',
#    'phone': '050352561515',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 51,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/김가네_20210114_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 778-8'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 2,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.3083795,
#    'app_order': True,
#    'lng': 126.980862162817,
#    'list_pos': 2,
#    'open': True,
#    'id': 571854,
#    'estimated_delivery_time': '16분',
#    'review_count': 18,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'superlist',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 2900, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210625102234326962_a341b0430655e4df002ef516f41f714f_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '17:30:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4753785800312,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['피자양식'],
#    'review_avg': 4.9,
#    'min_order_amount': 20000,
#    'distance': 1.33308010152,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '텍사스바베큐-사당점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 4,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '무료', 'basic': '2,900원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20210625_571854_텍사스바베큐-사당점_대표사진_300x300.jpg',
#    'address': '서울특별시 관악구 남현동 602-1 지하1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 1,
#    'adjusted_delivery_fee': 1000,
#    'is_available_delivery': True,
#    'new_rating': 0.537734,
#    'app_order': True,
#    'lng': 126.978385413834,
#    'list_pos': 3,
#    'open': True,
#    'id': 528238,
#    'estimated_delivery_time': '55~65분',
#    'review_count': 1582,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 821,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 14900},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 14900}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210721181909058631_57af6ae91ef1a7d424e1eeae7bad38c2_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': True,
#    'tags': ['excellent'],
#    'representative_menus': '',
#    'lat': 37.4849343277204,
#    'end': '00:50:00',
#    'discount_until': None,
#    'categories': ['피자양식', '프랜차이즈', '테이크아웃'],
#    'review_avg': 4.9,
#    'min_order_amount': 15900,
#    'distance': 1.20602973724,
#    'franchise_name': '(주)비에스비푸드 / 청년피자',
#    'except_cash': False,
#    'name': '청년피자-사당방배점',
#    'phone': '050352965404',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 706,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '1,000원'},
#    'logo_url': '/media/franchise_logos/청년피자_20210621_Franchise_crop_200x200_Dxc08kl.jpg',
#    'address': '서울특별시 동작구 사당동 150-13 150-13 1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 2,
#    'adjusted_delivery_fee': 1500,
#    'is_available_delivery': True,
#    'new_rating': 0.4710597,
#    'app_order': True,
#    'lng': 126.9790383,
#    'list_pos': 4,
#    'open': True,
#    'id': 236069,
#    'estimated_delivery_time': '70~80분',
#    'review_count': 4082,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 330,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 14000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201211181940304519_cc1ff01ce5006e9685747a0cd9827f00_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'address': '서울 동작구 사당동 67-8번지 1층 후라이드참잘하는집',
#    'lat': 37.4924529,
#    'end': '03:50:00',
#    'discount_until': None,
#    'categories': ['테이크아웃', '프랜차이즈', '치킨'],
#    'review_avg': 4.7,
#    'min_order_amount': 14000,
#    'distance': 1.50988976937,
#    'franchise_name': '더스카이팜후라이드참잘하는집지점 / 후라이드참잘하는집',
#    'except_cash': False,
#    'name': '후라이드참잘하는집-사당점',
#    'phone': '050352595537',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 470,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '1,500원'},
#    'logo_url': '/media/franchise_logos/후라이드참잘하는집_20201105_Franchise_crop_200x200.jpg'},
#   {'phone_order': True,
#    'free_delivery_threshold': 45000,
#    'section_pos': 3,
#    'adjusted_delivery_fee': 1900,
#    'is_available_delivery': True,
#    'new_rating': 0.3565483,
#    'app_order': True,
#    'lng': 126.994658186875,
#    'list_pos': 5,
#    'open': True,
#    'id': 502995,
#    'estimated_delivery_time': '33~43분',
#    'review_count': 886,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 379,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 6000,
#       'discount_mov': 18800},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 6000,
#       'discount_mov': 18800}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210907135553365328_005b0b30e6d7cf00336014679aea181c_tn.jpg',
#    'reachable': True,
#    'additional_discount': 6000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4826159849125,
#    'end': '02:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '찜탕', '테이크아웃', '한식'],
#    'review_avg': 4.9,
#    'min_order_amount': 16000,
#    'distance': 0.26062970442,
#    'franchise_name': '주식회사기영에프앤비 / 두찜',
#    'except_cash': False,
#    'name': '두마리찜닭두찜-서초방배점',
#    'phone': '050352938520',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 768,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료~1,900원'},
#    'logo_url': '/media/franchise_logos/두찜_20191219_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 922-24 922-24 1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 4,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.3314952,
#    'app_order': True,
#    'lng': 126.96440084069,
#    'list_pos': 6,
#    'open': True,
#    'id': 553593,
#    'estimated_delivery_time': '55~65분',
#    'review_count': 1082,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 32,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 16000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 16000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210901150721452880_83db8af7ad34c4b52ae3841e7d8665a1_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '12:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4756197660432,
#    'end': '02:50:00',
#    'discount_until': None,
#    'categories': ['치킨', '테이크아웃', '프랜차이즈'],
#    'review_avg': 4.9,
#    'min_order_amount': 12000,
#    'distance': 2.58431081897,
#    'franchise_name': '주식회사채움푸드 / 코리엔탈깻잎칩킨',
#    'except_cash': False,
#    'name': '코리엔탈깻잎두마리치킨-낙성대점',
#    'phone': '050352990793',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 945,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/코리엔탈깻잎두마리치킨_20200701_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 관악구 봉천동 1634-11 1634-11 지상1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 5,
#    'adjusted_delivery_fee': 3400,
#    'is_available_delivery': True,
#    'new_rating': 0.3096368,
#    'app_order': True,
#    'lng': 127.008321356362,
#    'list_pos': 7,
#    'open': True,
#    'id': 348355,
#    'estimated_delivery_time': '17분',
#    'review_count': 711,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 24,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201223142237116456_27c175f00c0a134b968bbd9b9d14f353_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'address': '서울 서초구 서초동 1542-1 지하1층 비18,19호',
#    'lat': 37.4915466145201,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['족발보쌈', '프랜차이즈'],
#    'review_avg': 4.6,
#    'min_order_amount': 12000,
#    'distance': 1.69816528699,
#    'franchise_name': '(주)놀부 / 놀부보쌈',
#    'except_cash': True,
#    'name': '놀부보쌈족발-서초점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 693,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '2,900원', 'basic': '3,400원'},
#    'logo_url': '/media/franchise_logos/놀부보쌈_20201223_Franchise_crop_200x200.jpg'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 6,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.3086346,
#    'app_order': True,
#    'lng': 126.966963251488,
#    'list_pos': 8,
#    'open': True,
#    'id': 296134,
#    'estimated_delivery_time': '49~59분',
#    'review_count': 1410,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 5,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190917141125461041_e53cf1f5c7b4969b2dcf2ce2a2df27f0_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '11:30:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4741365403551,
#    'end': '23:59:00',
#    'discount_until': None,
#    'categories': ['족발보쌈', '프랜차이즈'],
#    'review_avg': 4.8,
#    'min_order_amount': 18900,
#    'distance': 2.43892796951,
#    'franchise_name': '(주)푸디아 / 미스터보쌈5379',
#    'except_cash': False,
#    'name': '미스터보쌈족발-낙성대점',
#    'phone': '050712954644',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 14,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/미스터보쌈_20180823_Franchise이미지약정서_crop_200x200.jpg',
#    'address': '서울 관악구 봉천동 1642-11 1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 7,
#    'adjusted_delivery_fee': 1000,
#    'is_available_delivery': True,
#    'new_rating': 0.3078306,
#    'app_order': True,
#    'lng': 126.983067457484,
#    'list_pos': 9,
#    'open': True,
#    'id': 503492,
#    'estimated_delivery_time': '38~48분',
#    'review_count': 986,
#    'discount_from': '2021-11-10T11:45:00',
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 4,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181018163336282782_ef463ea2ae10afbec258e566e2077e8b_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4906982793625,
#    'end': '22:30:00',
#    'discount_until': '2021-11-10T21:44:59.999999',
#    'categories': ['테이크아웃', '프랜차이즈', '피자양식'],
#    'review_avg': 4.9,
#    'min_order_amount': 15000,
#    'distance': 1.11706576179,
#    'franchise_name': '(주)7번가사람들 / 7번가피자',
#    'except_cash': False,
#    'name': '7번가피자-방배사당점',
#    'phone': '050352938856',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 942,
#    'discount_percent': 10,
#    'delivery_fee_to_display': {'basic': '1,000원'},
#    'logo_url': '/media/franchise_logos/7번가피자_20210326_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 2253 1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 8,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.3043536,
#    'app_order': True,
#    'lng': 127.01983358,
#    'list_pos': 10,
#    'open': True,
#    'id': 487219,
#    'estimated_delivery_time': '50~60분',
#    'review_count': 1171,
#    'discount_from': '2021-11-10T18:00:00',
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 34,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210928141110387017_e8b104f2e9e7af49295a78df14ee7d1d_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '12:58:00',
#    'is_available_pickup': True,
#    'tags': ['excellent'],
#    'representative_menus': '',
#    'lat': 37.4952002356867,
#    'end': '02:30:00',
#    'discount_until': '2021-11-10T23:59:59.999999',
#    'categories': ['프랜차이즈', '치킨', '테이크아웃', '야식'],
#    'review_avg': 4.8,
#    'min_order_amount': 16000,
#    'distance': 2.78224577834,
#    'franchise_name': '(주)컬투에프앤비 / 컬투치킨',
#    'except_cash': False,
#    'name': '컬투치킨-서초1호점',
#    'phone': '050352921309',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1020,
#    'discount_percent': 5,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/컬투치킨_20180309_Franchise이미지약정서_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 9호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 9,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.2864421,
#    'app_order': True,
#    'lng': 126.98384912789,
#    'list_pos': 11,
#    'open': True,
#    'id': 412564,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 968,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 548,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 0},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142552546157_f0b60b578881144774d34ceb4d0785eb_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4859076399211,
#    'end': '00:30:00',
#    'discount_until': None,
#    'categories': ['야식', '고기구이', '프랜차이즈', '한식', '테이크아웃'],
#    'review_avg': 4.8,
#    'min_order_amount': 17000,
#    'distance': 0.7611439735200001,
#    'franchise_name': '(주)놀부 / 쫄면주는삼겹본능',
#    'except_cash': False,
#    'name': '쫄면주는삼겹본능by놀부-방배점',
#    'phone': '050718667053',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 959,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/쫄면주는삼겹본능_20210722_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 10,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.2614612,
#    'app_order': True,
#    'lng': 126.985610962595,
#    'list_pos': 12,
#    'open': True,
#    'id': 33988,
#    'estimated_delivery_time': '43~53분',
#    'review_count': 1354,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 9,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200611175830432554_82ba9c9b60ed8964fc1531ec29a508b6_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '11:30:00',
#    'is_available_pickup': True,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4940334306371,
#    'end': '01:00:00',
#    'discount_until': None,
#    'categories': ['치킨', '프랜차이즈', '야식', '테이크아웃'],
#    'review_avg': 4.6,
#    'min_order_amount': 15000,
#    'distance': 1.29441421503,
#    'franchise_name': '(주)농협목우촌 / 또래오래',
#    'except_cash': False,
#    'name': '또래오래-서초방배점',
#    'phone': '050352565480',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/또래오래_20201224_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 768-20 768-20 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 11,
#    'adjusted_delivery_fee': 4400,
#    'is_available_delivery': True,
#    'new_rating': 0.2386389,
#    'app_order': True,
#    'lng': 127.019713617149,
#    'list_pos': 13,
#    'open': True,
#    'id': 356319,
#    'estimated_delivery_time': '30분',
#    'review_count': 1179,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 703,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201120163412191907_3f827bcd37854c08255435d030e43b4a_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4952507905097,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '피자양식'],
#    'review_avg': 4.7,
#    'min_order_amount': 20000,
#    'distance': 2.7755216970000003,
#    'franchise_name': '(유)아웃백스테이크하우스코리아 / 아웃백스테이크하우스',
#    'except_cash': True,
#    'name': '아웃백-서초점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 1177,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '3,900원', 'basic': '4,400원'},
#    'logo_url': '/media/franchise_logos/아웃백스테이크하우스_20201120_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 주방26호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 13000,
#    'section_pos': 12,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.2298723,
#    'app_order': True,
#    'lng': 126.994844496436,
#    'list_pos': 14,
#    'open': True,
#    'id': 327229,
#    'estimated_delivery_time': '60~70분',
#    'review_count': 444,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 75,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210609180343749586_6d333ac5370e4c03f407cd63b2bbf3c1_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4852773427968,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['1인분주문', '버거', '프랜차이즈'],
#    'review_avg': 4.7,
#    'min_order_amount': 8000,
#    'distance': 0.32162211603999996,
#    'franchise_name': '(주)비케이알 / 버거킹',
#    'except_cash': False,
#    'name': '버거킹-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 199,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료~2,000원'},
#    'logo_url': '/media/franchise_logos/버거킹_20210609_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 925-3 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 13,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.227221,
#    'app_order': True,
#    'lng': 126.992550190204,
#    'list_pos': 15,
#    'open': True,
#    'id': 294661,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 355,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 361,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 12000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 12000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210602113230507936_6be89eb29d03c0048e4754c176583986_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:30:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4888473318139,
#    'end': '20:30:00',
#    'discount_until': None,
#    'categories': ['카페디저트', '프랜차이즈', '테이크아웃'],
#    'review_avg': 4.7,
#    'min_order_amount': 12000,
#    'distance': 0.59360636718,
#    'franchise_name': '(주)섹타나인양재지점 / 던킨도너츠',
#    'except_cash': True,
#    'name': '던킨-내방점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/던킨도너츠_20181228_Franchise이미지약정서_crop_200x200_fG79bfM.png',
#    'address': '서울 서초구 방배동 852-16'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 14,
#    'adjusted_delivery_fee': 4400,
#    'is_available_delivery': True,
#    'new_rating': 0.2251996,
#    'app_order': True,
#    'lng': 127.019837040682,
#    'list_pos': 16,
#    'open': True,
#    'id': 477188,
#    'estimated_delivery_time': '29분',
#    'review_count': 306,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 561,
#    'discounts': {'delivery_fee': {'funding': 3000, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210105101758905543_759c74f1750da0e1c460897d7733a3c5_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.495193688217,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '피자양식'],
#    'review_avg': 4.8,
#    'min_order_amount': 20000,
#    'distance': 2.78217653971,
#    'franchise_name': '씨제이푸드빌(주) / 빕스',
#    'except_cash': True,
#    'name': '빕스얌딜리버리-서초점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 305,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '900원', 'basic': '4,400원'},
#    'logo_url': '/media/franchise_logos/빕스_20210105_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하1층 101호 내 22호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 15,
#    'adjusted_delivery_fee': 0,
#    'is_available_delivery': True,
#    'new_rating': 0.2016609,
#    'app_order': True,
#    'lng': 126.9877312,
#    'list_pos': 17,
#    'open': True,
#    'id': 33630,
#    'estimated_delivery_time': '33~43분',
#    'review_count': 582,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 41,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 5000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201211181323617330_6f3535ec40b1fba1fc37be5a0c04d4bb_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO', 'relayo'],
#    'representative_menus': '',
#    'address': '서울 서초구 방배동 758-2 삼호상가 1층 118호',
#    'lat': 37.4966162999325,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '피자양식'],
#    'review_avg': 4.7,
#    'min_order_amount': 20000,
#    'distance': 1.50163243699,
#    'franchise_name': '한국파파존스(주) / 파파존스',
#    'except_cash': False,
#    'name': '파파존스피자-방배점',
#    'phone': '050352588699',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 71,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료'},
#    'logo_url': '/media/franchise_logos/파파존스_20200625_Franchise_crop_200x200.jpg'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 16,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.1865767,
#    'app_order': True,
#    'lng': 126.9962801,
#    'list_pos': 18,
#    'open': True,
#    'id': 309760,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 99,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 648,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201216172414729435_53a051bc3383ad3aa1d4add2ad938c6f_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4828112999307,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['카페디저트', '프랜차이즈'],
#    'review_avg': 4.5,
#    'min_order_amount': 12000,
#    'distance': 0.39133190380000005,
#    'franchise_name': '투썸플레이스주식회사 / 투썸플레이스',
#    'except_cash': True,
#    'name': '투썸플레이스-방배역점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 83,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/투썸플레이스_20200323_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 910-14 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 17,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.1857439,
#    'app_order': True,
#    'lng': 126.996361190021,
#    'list_pos': 19,
#    'open': True,
#    'id': 545162,
#    'estimated_delivery_time': '21분',
#    'review_count': 126,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 1096,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20211108133157085193_b5ad6d48b4f7d9916440efad814ca98d_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '12:30:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4818781258087,
#    'end': '22:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '샌드위치', '카페디저트'],
#    'review_avg': 4.5,
#    'min_order_amount': 8000,
#    'distance': 0.43133558483,
#    'franchise_name': '주식회사골든하인드 / 에그드랍',
#    'except_cash': True,
#    'name': '에그드랍-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '2,900원'},
#    'logo_url': '/media/franchise_logos/에그드랍OD_20211108_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 911-16 911-16 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 18,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.170436,
#    'app_order': True,
#    'lng': 126.983253206562,
#    'list_pos': 20,
#    'open': True,
#    'id': 458334,
#    'estimated_delivery_time': '47~57분',
#    'review_count': 0,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 1069,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 11000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 11000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200618110432510737_df539b0d143725c751cc0fe2863350c8_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4873012630914,
#    'end': '22:30:00',
#    'discount_until': None,
#    'categories': ['피자양식', '프랜차이즈', '테이크아웃', '1인분주문'],
#    'review_avg': 0.0,
#    'min_order_amount': 11000,
#    'distance': 0.87354275489,
#    'franchise_name': '(주)섹타나인양재지점 / PBDELI',
#    'except_cash': True,
#    'name': 'PB델리-방배현대점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/PBDELI_20200602_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 1461 인텔고시원 1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 19,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.1643338,
#    'app_order': True,
#    'lng': 126.985836588694,
#    'list_pos': 21,
#    'open': True,
#    'id': 252710,
#    'estimated_delivery_time': '56~66분',
#    'review_count': 1039,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 71,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 16000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 16000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210315164332919147_ed6739c1b1346c6033574db2f9b0a303_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '12:00:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4923623568624,
#    'end': '23:30:00',
#    'discount_until': None,
#    'categories': ['야식', '치킨', '테이크아웃', '프랜차이즈'],
#    'review_avg': 4.6,
#    'min_order_amount': 16000,
#    'distance': 1.11991640906,
#    'franchise_name': '(주)페리카나 / 페리카나',
#    'except_cash': False,
#    'name': '페리카나-방배본점',
#    'phone': '050712913139',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 891,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/페리카나_20210616_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 789-17 789-17'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 20,
#    'adjusted_delivery_fee': 0,
#    'is_available_delivery': True,
#    'new_rating': 0.1642172,
#    'app_order': True,
#    'lng': 126.993072784527,
#    'list_pos': 22,
#    'open': True,
#    'id': 336027,
#    'estimated_delivery_time': '38~48분',
#    'review_count': 318,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 85,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 6000,
#       'discount_mov': 19900}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210803135635842339_a989b0b91a473801e2db0f91391a3e87_tn.jpg',
#    'reachable': True,
#    'additional_discount': 6000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO', 'relayo'],
#    'representative_menus': '',
#    'address': '서울 서초구 방배동 851-6 태창빌딩 1층 가호',
#    'lat': 37.4892925371193,
#    'end': '22:30:00',
#    'discount_until': None,
#    'categories': ['피자양식', '프랜차이즈'],
#    'review_avg': 4.5,
#    'min_order_amount': 19900,
#    'distance': 0.64842071559,
#    'franchise_name': '한국피자헛유한회사 / 피자헛',
#    'except_cash': False,
#    'name': '피자헛-방배2호점',
#    'phone': '050712992122',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 28,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료'},
#    'logo_url': '/media/franchise_logos/피자헛_20170612_Franchise이미지약정서_crop_200x200.jpg'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 21,
#    'adjusted_delivery_fee': 3900,
#    'is_available_delivery': True,
#    'new_rating': 0.1560712,
#    'app_order': True,
#    'lng': 126.994603640399,
#    'list_pos': 23,
#    'open': True,
#    'id': 287091,
#    'estimated_delivery_time': '27분',
#    'review_count': 442,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 301,
#    'discounts': {'delivery_fee': {'funding': 1900, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 16000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201209174451671994_270baa1a9c7c2ed7e428c255658bbd45_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.5054333512309,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '치킨'],
#    'review_avg': 4.8,
#    'min_order_amount': 16000,
#    'distance': 2.44675516556,
#    'franchise_name': '주식회사한울 / 돈치킨',
#    'except_cash': True,
#    'name': '돈치킨-반포점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 7,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '1,500원', 'basic': '3,900원'},
#    'logo_url': '/media/franchise_logos/돈피자OD_20210203_Franchise_crop_200x200_GjpHoKV_mneMXsS.jpg',
#    'address': '서울 서초구 반포동 2-8 신반포상가 201호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 22,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.1553866,
#    'app_order': True,
#    'lng': 126.98384912789,
#    'list_pos': 24,
#    'open': True,
#    'id': 412563,
#    'estimated_delivery_time': '50~60분',
#    'review_count': 495,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 654,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 0},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609141652474942_28f5298ba9060adba417159b6e431f6b_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4859076399211,
#    'end': '00:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '테이크아웃', '한식', '야식', '찜탕'],
#    'review_avg': 4.9,
#    'min_order_amount': 15000,
#    'distance': 0.7611439735200001,
#    'franchise_name': '(주)놀부 / 흥부찜닭',
#    'except_cash': False,
#    'name': '흥부찜닭by놀부-방배점',
#    'phone': '050718666886',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 493,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/흥부찜닭_20210722_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 23,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.1405696,
#    'app_order': True,
#    'lng': 126.9806025,
#    'list_pos': 25,
#    'open': True,
#    'id': 61311,
#    'estimated_delivery_time': '30~40분',
#    'review_count': 936,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 28,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200408102755524276_d948de5f76247ad7a4310389d32a94ac_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '11:20:00',
#    'is_available_pickup': True,
#    'tags': [],
#    'representative_menus': '',
#    'address': '서울 동작구 사당동 139-63번지 1,2층',
#    'lat': 37.4868015,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['야식', '프랜차이즈', '족발보쌈', '테이크아웃'],
#    'review_avg': 4.6,
#    'min_order_amount': 25000,
#    'distance': 1.0643114741500002,
#    'franchise_name': '(주)원앤원 / 원할머니보쌈',
#    'except_cash': False,
#    'name': '원할머니보쌈족발-이수역점',
#    'phone': '050352563983',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 936,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/원할머니보쌈02_20150716_Franchise이미지약정서_crop_200x200.jpg'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 24,
#    'adjusted_delivery_fee': 1500,
#    'is_available_delivery': True,
#    'new_rating': 0.1374698,
#    'app_order': True,
#    'lng': 126.998381992716,
#    'list_pos': 26,
#    'open': True,
#    'id': 250513,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 330,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 80,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 7000,
#       'discount_mov': 19900}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200319134444642414_4f486eaab1f5064627eaf6a518c11907_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 1,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO', 'relayo'],
#    'representative_menus': '',
#    'address': '서울특별시 서초구 방배동 984-4 미피하우스 984-4 미피하우스 1층',
#    'lat': 37.4813573823629,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '피자양식'],
#    'review_avg': 4.6,
#    'min_order_amount': 19900,
#    'distance': 0.6177742481499999,
#    'franchise_name': '[Brand]미스터피자',
#    'except_cash': False,
#    'name': '미스터피자-방배본점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 238,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '1,500원'},
#    'logo_url': '/media/franchise_logos/미스터피자_20200319_Franchise_crop_200x200.jpg'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 25,
#    'adjusted_delivery_fee': 0,
#    'is_available_delivery': True,
#    'new_rating': 0.1319846,
#    'app_order': True,
#    'lng': 126.999287457132,
#    'list_pos': 27,
#    'open': True,
#    'id': 567462,
#    'estimated_delivery_time': '35~45분',
#    'review_count': 57,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 652,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 5000,
#       'discount_mov': 21900}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210908101636002485_8fbb9bd8825e90cfc24e4da808366799_tn.jpg',
#    'reachable': True,
#    'additional_discount': 5000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '11:30:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'address': '서울 서초구 방배동 985-6 서진빌딩',
#    'lat': 37.481457724664,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '피자양식'],
#    'review_avg': 4.7,
#    'min_order_amount': 21900,
#    'distance': 0.68819026458,
#    'franchise_name': '(주)청오디피케이 / 도미노피자',
#    'except_cash': True,
#    'name': '도미노피자-방배역점',
#    'phone': '050702780760',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료'},
#    'logo_url': '/media/franchise_logos/도미노피자_20190102_Franchise이미지약정서_crop_200x200.jpg'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 26,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.1303217,
#    'app_order': True,
#    'lng': 126.984876617489,
#    'list_pos': 28,
#    'open': True,
#    'id': 253137,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 480,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 7,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 15000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201221182259967766_ea8863c6bc7b22fa56f9f2f4ab382bb1_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '12:30:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'address': '서울 서초구 방배동 767-24 1층',
#    'lat': 37.4940211609975,
#    'end': '23:40:00',
#    'discount_until': None,
#    'categories': ['테이크아웃', '야식', '프랜차이즈', '치킨'],
#    'review_avg': 4.8,
#    'min_order_amount': 13000,
#    'distance': 1.32244793768,
#    'franchise_name': '(주)혜인식품 / 네네치킨',
#    'except_cash': False,
#    'name': '네네치킨-방배본동점',
#    'phone': '050712913555',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 480,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/네네치킨_20200310_Franchise_crop_200x200.jpg'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 27,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.1244457,
#    'app_order': True,
# ...
#    'is_available_delivery': True,
#    'new_rating': 0.4299983,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.977323445093,
#    'list_pos': 51,
#    'open': True,
#    'id': 424030,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 1361,
#    'discount_from': '2021-11-10T12:00:00',
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210513130000000000_820861c6ed867fadaed34597dcbcde72_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4835715285553,
#    'end': '09:59:00',
#    'discount_until': '2021-11-10T23:59:59.999999',
#    'categories': ['야식', '치킨', '테이크아웃'],
#    'review_avg': 4.8,
#    'min_order_amount': 10800,
#    'distance': 1.28961531244,
#    'minimum_pickup_minutes': 10,
#    'except_cash': False,
#    'name': '맛카오치킨',
#    'phone': '050352848066',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1106,
#    'discount_percent': 5,
#    'delivery_fee_to_display': {'basic': '1,500원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20200310_424030_맛카오치킨_대표사진_300x300.jpg',
#    'address': '서울 동작구 사당동 1001-32 1층'},
#   {'phone_order': True,
#    'section_pos': 6,
#    'adjusted_delivery_fee': 0,
#    'is_available_delivery': True,
#    'new_rating': 0.6336301,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.9758141,
#    'list_pos': 52,
#    'open': True,
#    'id': 243115,
#    'estimated_delivery_time': '40~50분',
#    'review_count': 4287,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 3,
#    'discounts': {'additional': {'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201214171955319908_d9bc449aca19df9bb08f0b1490d9d460_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 40,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO', 'relayo', 'excellent'],
#    'representative_menus': '',
#    'lat': 37.482356,
#    'end': '23:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '피자양식', '테이크아웃'],
#    'review_avg': 4.9,
#    'min_order_amount': 15900,
#    'distance': 1.42878452413,
#    'franchise_name': '(주)반올림피자샵 / 피자샵',
#    'except_cash': False,
#    'name': '반올림피자샵-사당방배점',
#    'phone': '050712903212',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1331,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료'},
#    'logo_url': '/media/franchise_logos/피자샵_20200303_Franchise_crop_200x200.jpg',
#    'address': '서울 동작구 사당동 321-103 1층'},
#   {'phone_order': False,
#    'section_pos': 7,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.5795212,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.983134124098,
#    'list_pos': 53,
#    'open': True,
#    'id': 239906,
#    'estimated_delivery_time': '21분',
#    'review_count': 1094,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 900, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210728104439423527_fbc5df0f659cb541b94056cacc841c14_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '17:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4882560769312,
#    'end': '20:30:00',
#    'discount_until': None,
#    'categories': ['중식'],
#    'review_avg': 4.5,
#    'min_order_amount': 10000,
#    'distance': 0.9378578538100001,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '강릉교동짬뽕-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '1,500원', 'basic': '2,900원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20210805_239906_강릉교동짬뽕-방배점_대표사진_300x300.jpg',
#    'address': '서울특별시 서초구 방배동 1847 대신교회 1847 대신교회 1층'},
#   {'phone_order': True,
#    'section_pos': 8,
#    'adjusted_delivery_fee': 0,
#    'is_available_delivery': True,
#    'new_rating': 0.563945,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.9832261,
#    'list_pos': 54,
#    'open': True,
#    'id': 29011,
#    'estimated_delivery_time': '39~49분',
#    'review_count': 2400,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210419110000000000_5a65485d186dbf97e19c3857ac56636d_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4872472999312,
#    'end': '20:30:00',
#    'discount_until': None,
#    'categories': ['중식'],
#    'review_avg': 4.4,
#    'min_order_amount': 9000,
#    'distance': 0.87278507803,
#    'minimum_pickup_minutes': 0,
#    'except_cash': False,
#    'name': '황궁쟁반짜장-서경',
#    'phone': '050352569049',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 3,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료'},
#    'logo_url': '/media/restaurant_logos/짜장면01_20120524_FoodAD_crop_200x200_32.jpg',
#    'address': '서울 서초구 방배4동 1461'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 9,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': -0.2846922,
#    'app_order': True,
#    'lng': 126.980358263752,
#    'list_pos': 55,
#    'open': True,
#    'id': 1024089,
#    'estimated_delivery_time': '23분',
#    'review_count': 3,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20211101172834808848_44644d2ccd90c788cadcc2eea33ee410_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': True,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.476008592048,
#    'end': '20:30:00',
#    'discount_until': None,
#    'categories': ['피자양식', '일식돈까스', '한식'],
#    'review_avg': 4.3,
#    'min_order_amount': 12000,
#    'distance': 1.3205642753300002,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '미찬돈까스&파스타',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 3,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '2,900원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20211025_1024089_미찬돈까스n파스타_대표사진_300x300.jpg',
#    'address': '서울특별시 관악구 남현동 1060-18 범평빌딩 지하1층'},
#   {'phone_order': True,
#    'section_pos': 10,
#    'adjusted_delivery_fee': 1000,
#    'is_available_delivery': True,
#    'new_rating': 0.3078306,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.983067457484,
#    'list_pos': 56,
#    'open': True,
#    'id': 503492,
#    'estimated_delivery_time': '38~48분',
#    'review_count': 986,
#    'discount_from': '2021-11-10T11:45:00',
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 4,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181018163336282782_ef463ea2ae10afbec258e566e2077e8b_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4906982793625,
#    'end': '22:30:00',
#    'discount_until': '2021-11-10T21:44:59.999999',
#    'categories': ['테이크아웃', '프랜차이즈', '피자양식'],
#    'review_avg': 4.9,
#    'min_order_amount': 15000,
#    'distance': 1.11706576179,
#    'franchise_name': '(주)7번가사람들 / 7번가피자',
#    'except_cash': False,
#    'name': '7번가피자-방배사당점',
#    'phone': '050352938856',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 942,
#    'discount_percent': 10,
#    'delivery_fee_to_display': {'basic': '1,000원'},
#    'logo_url': '/media/franchise_logos/7번가피자_20210326_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 2253 1층'},
#   {'phone_order': True,
#    'section_pos': 11,
#    'adjusted_delivery_fee': 1000,
#    'is_available_delivery': True,
#    'new_rating': 0.537734,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.978385413834,
#    'list_pos': 57,
#    'open': True,
#    'id': 528238,
#    'estimated_delivery_time': '55~65분',
#    'review_count': 1582,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 821,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 14900},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 14900}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210721181909058631_57af6ae91ef1a7d424e1eeae7bad38c2_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': True,
#    'tags': ['excellent'],
#    'representative_menus': '',
#    'lat': 37.4849343277204,
#    'end': '00:50:00',
#    'discount_until': None,
#    'categories': ['피자양식', '프랜차이즈', '테이크아웃'],
#    'review_avg': 4.9,
#    'min_order_amount': 15900,
#    'distance': 1.20602973724,
#    'franchise_name': '(주)비에스비푸드 / 청년피자',
#    'except_cash': False,
#    'name': '청년피자-사당방배점',
#    'phone': '050352965404',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 706,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '1,000원'},
#    'logo_url': '/media/franchise_logos/청년피자_20210621_Franchise_crop_200x200_Dxc08kl.jpg',
#    'address': '서울특별시 동작구 사당동 150-13 150-13 1층'},
#   {'phone_order': False,
#    'section_pos': 12,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.5297729,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.994540317825,
#    'list_pos': 58,
#    'open': True,
#    'id': 569027,
#    'estimated_delivery_time': '13분',
#    'review_count': 234,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 1900, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210517181040721688_98c469d002ee0e339def4e079e8c7b39_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '11:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4850798399444,
#    'end': '21:00:00',
#    'discount_until': None,
#    'categories': ['분식'],
#    'review_avg': 4.8,
#    'min_order_amount': 12000,
#    'distance': 0.28697051738,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '홍미단블랙딜리버리',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '500원', 'basic': '2,900원'},
#    'logo_url': '/media/restaurant_logos/DHK촬영_20210520_569027_홍미단블랙딜리버리_대표사진_300x300_xVseQ4a.jpg',
#    'address': '서울 서초구 방배동 925-19 1층'},
#   {'phone_order': False,
#    'section_pos': 13,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.5181116,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.983402953314,
#    'list_pos': 59,
#    'open': True,
#    'id': 574509,
#    'estimated_delivery_time': '19분',
#    'review_count': 175,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 2900, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210720103514843292_3f0009cc923fdb0476bc4eeddcd0f492_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4874676953048,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['한식', '프랜차이즈', '1인분주문', '고기구이'],
#    'review_avg': 4.6,
#    'min_order_amount': 8900,
#    'distance': 0.8711246434800001,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '덮다-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 175,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '무료', 'basic': '2,900원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20210720_574509_덮다-방배점_대표사진_300x300.jpg',
#    'address': '서울 서초구 방배동 1458 2층'},
#   {'phone_order': True,
#    'section_pos': 14,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.3043536,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 127.01983358,
#    'list_pos': 60,
#    'open': True,
#    'id': 487219,
#    'estimated_delivery_time': '50~60분',
#    'review_count': 1171,
#    'discount_from': '2021-11-10T18:00:00',
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 34,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210928141110387017_e8b104f2e9e7af49295a78df14ee7d1d_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '12:58:00',
#    'is_available_pickup': True,
#    'tags': ['excellent'],
#    'representative_menus': '',
#    'lat': 37.4952002356867,
#    'end': '02:30:00',
#    'discount_until': '2021-11-10T23:59:59.999999',
#    'categories': ['프랜차이즈', '치킨', '테이크아웃', '야식'],
#    'review_avg': 4.8,
#    'min_order_amount': 16000,
#    'distance': 2.78224577834,
#    'franchise_name': '(주)컬투에프앤비 / 컬투치킨',
#    'except_cash': False,
#    'name': '컬투치킨-서초1호점',
#    'phone': '050352921309',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1020,
#    'discount_percent': 5,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/컬투치킨_20180309_Franchise이미지약정서_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 9호'}]}

# %%
ygy_data['restaurants'] # 식당정보가 담긴 dict
# Out:
# [{'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 1,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.2523366,
#   'app_order': True,
#   'lng': 126.9860396,
#   'list_pos': 1,
#   'open': True,
#   'id': 54915,
#   'estimated_delivery_time': '25~35분',
#   'review_count': 1375,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'superlist',
#   'restaurant_type': 'food',
#   'franchise_id': 82,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181004182813010545_d61c21551fb145915b554bc893ffe4f5_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': '주식회사김가네 / 김가네',
#   'thumbnail_message': '',
#   'begin': '09:30:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.49387,
#   'end': '20:20:00',
#   'discount_until': None,
#   'categories': ['분식', '한식', '프랜차이즈'],
#   'review_avg': 4.6,
#   'min_order_amount': 15000,
#   'distance': 1.26198076014,
#   'minimum_pickup_minutes': 0,
#   'except_cash': False,
#   'name': '김가네-방배본동점',
#   'phone': '050352561515',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 51,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/김가네_20210114_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 778-8'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 2,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.3083795,
#   'app_order': True,
#   'lng': 126.980862162817,
#   'list_pos': 2,
#   'open': True,
#   'id': 571854,
#   'estimated_delivery_time': '16분',
#   'review_count': 18,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'superlist',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 2900, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210625102234326962_a341b0430655e4df002ef516f41f714f_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '17:30:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4753785800312,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['피자양식'],
#   'review_avg': 4.9,
#   'min_order_amount': 20000,
#   'distance': 1.33308010152,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '텍사스바베큐-사당점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 4,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '무료', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20210625_571854_텍사스바베큐-사당점_대표사진_300x300.jpg',
#   'address': '서울특별시 관악구 남현동 602-1 지하1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 1,
#   'adjusted_delivery_fee': 1000,
#   'is_available_delivery': True,
#   'new_rating': 0.537734,
#   'app_order': True,
#   'lng': 126.978385413834,
#   'list_pos': 3,
#   'open': True,
#   'id': 528238,
#   'estimated_delivery_time': '55~65분',
#   'review_count': 1582,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 821,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 14900},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 14900}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210721181909058631_57af6ae91ef1a7d424e1eeae7bad38c2_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': True,
#   'tags': ['excellent'],
#   'representative_menus': '',
#   'lat': 37.4849343277204,
#   'end': '00:50:00',
#   'discount_until': None,
#   'categories': ['피자양식', '프랜차이즈', '테이크아웃'],
#   'review_avg': 4.9,
#   'min_order_amount': 15900,
#   'distance': 1.20602973724,
#   'franchise_name': '(주)비에스비푸드 / 청년피자',
#   'except_cash': False,
#   'name': '청년피자-사당방배점',
#   'phone': '050352965404',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 706,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '1,000원'},
#   'logo_url': '/media/franchise_logos/청년피자_20210621_Franchise_crop_200x200_Dxc08kl.jpg',
#   'address': '서울특별시 동작구 사당동 150-13 150-13 1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 2,
#   'adjusted_delivery_fee': 1500,
#   'is_available_delivery': True,
#   'new_rating': 0.4710597,
#   'app_order': True,
#   'lng': 126.9790383,
#   'list_pos': 4,
#   'open': True,
#   'id': 236069,
#   'estimated_delivery_time': '70~80분',
#   'review_count': 4082,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 330,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 14000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201211181940304519_cc1ff01ce5006e9685747a0cd9827f00_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'address': '서울 동작구 사당동 67-8번지 1층 후라이드참잘하는집',
#   'lat': 37.4924529,
#   'end': '03:50:00',
#   'discount_until': None,
#   'categories': ['테이크아웃', '프랜차이즈', '치킨'],
#   'review_avg': 4.7,
#   'min_order_amount': 14000,
#   'distance': 1.50988976937,
#   'franchise_name': '더스카이팜후라이드참잘하는집지점 / 후라이드참잘하는집',
#   'except_cash': False,
#   'name': '후라이드참잘하는집-사당점',
#   'phone': '050352595537',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 470,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '1,500원'},
#   'logo_url': '/media/franchise_logos/후라이드참잘하는집_20201105_Franchise_crop_200x200.jpg'},
#  {'phone_order': True,
#   'free_delivery_threshold': 45000,
#   'section_pos': 3,
#   'adjusted_delivery_fee': 1900,
#   'is_available_delivery': True,
#   'new_rating': 0.3565483,
#   'app_order': True,
#   'lng': 126.994658186875,
#   'list_pos': 5,
#   'open': True,
#   'id': 502995,
#   'estimated_delivery_time': '33~43분',
#   'review_count': 886,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 379,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 6000,
#      'discount_mov': 18800},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 6000,
#      'discount_mov': 18800}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210907135553365328_005b0b30e6d7cf00336014679aea181c_tn.jpg',
#   'reachable': True,
#   'additional_discount': 6000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4826159849125,
#   'end': '02:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '찜탕', '테이크아웃', '한식'],
#   'review_avg': 4.9,
#   'min_order_amount': 16000,
#   'distance': 0.26062970442,
#   'franchise_name': '주식회사기영에프앤비 / 두찜',
#   'except_cash': False,
#   'name': '두마리찜닭두찜-서초방배점',
#   'phone': '050352938520',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 768,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료~1,900원'},
#   'logo_url': '/media/franchise_logos/두찜_20191219_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 922-24 922-24 1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 4,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.3314952,
#   'app_order': True,
#   'lng': 126.96440084069,
#   'list_pos': 6,
#   'open': True,
#   'id': 553593,
#   'estimated_delivery_time': '55~65분',
#   'review_count': 1082,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 32,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 16000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 16000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210901150721452880_83db8af7ad34c4b52ae3841e7d8665a1_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '12:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4756197660432,
#   'end': '02:50:00',
#   'discount_until': None,
#   'categories': ['치킨', '테이크아웃', '프랜차이즈'],
#   'review_avg': 4.9,
#   'min_order_amount': 12000,
#   'distance': 2.58431081897,
#   'franchise_name': '주식회사채움푸드 / 코리엔탈깻잎칩킨',
#   'except_cash': False,
#   'name': '코리엔탈깻잎두마리치킨-낙성대점',
#   'phone': '050352990793',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 945,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/코리엔탈깻잎두마리치킨_20200701_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 관악구 봉천동 1634-11 1634-11 지상1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 5,
#   'adjusted_delivery_fee': 3400,
#   'is_available_delivery': True,
#   'new_rating': 0.3096368,
#   'app_order': True,
#   'lng': 127.008321356362,
#   'list_pos': 7,
#   'open': True,
#   'id': 348355,
#   'estimated_delivery_time': '17분',
#   'review_count': 711,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 24,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201223142237116456_27c175f00c0a134b968bbd9b9d14f353_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'address': '서울 서초구 서초동 1542-1 지하1층 비18,19호',
#   'lat': 37.4915466145201,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['족발보쌈', '프랜차이즈'],
#   'review_avg': 4.6,
#   'min_order_amount': 12000,
#   'distance': 1.69816528699,
#   'franchise_name': '(주)놀부 / 놀부보쌈',
#   'except_cash': True,
#   'name': '놀부보쌈족발-서초점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 693,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '2,900원', 'basic': '3,400원'},
#   'logo_url': '/media/franchise_logos/놀부보쌈_20201223_Franchise_crop_200x200.jpg'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 6,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.3086346,
#   'app_order': True,
#   'lng': 126.966963251488,
#   'list_pos': 8,
#   'open': True,
#   'id': 296134,
#   'estimated_delivery_time': '49~59분',
#   'review_count': 1410,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 5,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190917141125461041_e53cf1f5c7b4969b2dcf2ce2a2df27f0_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '11:30:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4741365403551,
#   'end': '23:59:00',
#   'discount_until': None,
#   'categories': ['족발보쌈', '프랜차이즈'],
#   'review_avg': 4.8,
#   'min_order_amount': 18900,
#   'distance': 2.43892796951,
#   'franchise_name': '(주)푸디아 / 미스터보쌈5379',
#   'except_cash': False,
#   'name': '미스터보쌈족발-낙성대점',
#   'phone': '050712954644',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 14,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/미스터보쌈_20180823_Franchise이미지약정서_crop_200x200.jpg',
#   'address': '서울 관악구 봉천동 1642-11 1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 7,
#   'adjusted_delivery_fee': 1000,
#   'is_available_delivery': True,
#   'new_rating': 0.3078306,
#   'app_order': True,
#   'lng': 126.983067457484,
#   'list_pos': 9,
#   'open': True,
#   'id': 503492,
#   'estimated_delivery_time': '38~48분',
#   'review_count': 986,
#   'discount_from': '2021-11-10T11:45:00',
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 4,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181018163336282782_ef463ea2ae10afbec258e566e2077e8b_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4906982793625,
#   'end': '22:30:00',
#   'discount_until': '2021-11-10T21:44:59.999999',
#   'categories': ['테이크아웃', '프랜차이즈', '피자양식'],
#   'review_avg': 4.9,
#   'min_order_amount': 15000,
#   'distance': 1.11706576179,
#   'franchise_name': '(주)7번가사람들 / 7번가피자',
#   'except_cash': False,
#   'name': '7번가피자-방배사당점',
#   'phone': '050352938856',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 942,
#   'discount_percent': 10,
#   'delivery_fee_to_display': {'basic': '1,000원'},
#   'logo_url': '/media/franchise_logos/7번가피자_20210326_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 2253 1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 8,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.3043536,
#   'app_order': True,
#   'lng': 127.01983358,
#   'list_pos': 10,
#   'open': True,
#   'id': 487219,
#   'estimated_delivery_time': '50~60분',
#   'review_count': 1171,
#   'discount_from': '2021-11-10T18:00:00',
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 34,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210928141110387017_e8b104f2e9e7af49295a78df14ee7d1d_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '12:58:00',
#   'is_available_pickup': True,
#   'tags': ['excellent'],
#   'representative_menus': '',
#   'lat': 37.4952002356867,
#   'end': '02:30:00',
#   'discount_until': '2021-11-10T23:59:59.999999',
#   'categories': ['프랜차이즈', '치킨', '테이크아웃', '야식'],
#   'review_avg': 4.8,
#   'min_order_amount': 16000,
#   'distance': 2.78224577834,
#   'franchise_name': '(주)컬투에프앤비 / 컬투치킨',
#   'except_cash': False,
#   'name': '컬투치킨-서초1호점',
#   'phone': '050352921309',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1020,
#   'discount_percent': 5,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/컬투치킨_20180309_Franchise이미지약정서_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 9호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 9,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.2864421,
#   'app_order': True,
#   'lng': 126.98384912789,
#   'list_pos': 11,
#   'open': True,
#   'id': 412564,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 968,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 548,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 0},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142552546157_f0b60b578881144774d34ceb4d0785eb_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4859076399211,
#   'end': '00:30:00',
#   'discount_until': None,
#   'categories': ['야식', '고기구이', '프랜차이즈', '한식', '테이크아웃'],
#   'review_avg': 4.8,
#   'min_order_amount': 17000,
#   'distance': 0.7611439735200001,
#   'franchise_name': '(주)놀부 / 쫄면주는삼겹본능',
#   'except_cash': False,
#   'name': '쫄면주는삼겹본능by놀부-방배점',
#   'phone': '050718667053',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 959,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/쫄면주는삼겹본능_20210722_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 10,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.2614612,
#   'app_order': True,
#   'lng': 126.985610962595,
#   'list_pos': 12,
#   'open': True,
#   'id': 33988,
#   'estimated_delivery_time': '43~53분',
#   'review_count': 1354,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 9,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200611175830432554_82ba9c9b60ed8964fc1531ec29a508b6_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '11:30:00',
#   'is_available_pickup': True,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4940334306371,
#   'end': '01:00:00',
#   'discount_until': None,
#   'categories': ['치킨', '프랜차이즈', '야식', '테이크아웃'],
#   'review_avg': 4.6,
#   'min_order_amount': 15000,
#   'distance': 1.29441421503,
#   'franchise_name': '(주)농협목우촌 / 또래오래',
#   'except_cash': False,
#   'name': '또래오래-서초방배점',
#   'phone': '050352565480',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/또래오래_20201224_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 768-20 768-20 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 11,
#   'adjusted_delivery_fee': 4400,
#   'is_available_delivery': True,
#   'new_rating': 0.2386389,
#   'app_order': True,
#   'lng': 127.019713617149,
#   'list_pos': 13,
#   'open': True,
#   'id': 356319,
#   'estimated_delivery_time': '30분',
#   'review_count': 1179,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 703,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201120163412191907_3f827bcd37854c08255435d030e43b4a_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4952507905097,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '피자양식'],
#   'review_avg': 4.7,
#   'min_order_amount': 20000,
#   'distance': 2.7755216970000003,
#   'franchise_name': '(유)아웃백스테이크하우스코리아 / 아웃백스테이크하우스',
#   'except_cash': True,
#   'name': '아웃백-서초점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 1177,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '3,900원', 'basic': '4,400원'},
#   'logo_url': '/media/franchise_logos/아웃백스테이크하우스_20201120_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 주방26호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 13000,
#   'section_pos': 12,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.2298723,
#   'app_order': True,
#   'lng': 126.994844496436,
#   'list_pos': 14,
#   'open': True,
#   'id': 327229,
#   'estimated_delivery_time': '60~70분',
#   'review_count': 444,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 75,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210609180343749586_6d333ac5370e4c03f407cd63b2bbf3c1_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4852773427968,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['1인분주문', '버거', '프랜차이즈'],
#   'review_avg': 4.7,
#   'min_order_amount': 8000,
#   'distance': 0.32162211603999996,
#   'franchise_name': '(주)비케이알 / 버거킹',
#   'except_cash': False,
#   'name': '버거킹-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 199,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료~2,000원'},
#   'logo_url': '/media/franchise_logos/버거킹_20210609_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 925-3 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 13,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.227221,
#   'app_order': True,
#   'lng': 126.992550190204,
#   'list_pos': 15,
#   'open': True,
#   'id': 294661,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 355,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 361,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 12000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 12000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210602113230507936_6be89eb29d03c0048e4754c176583986_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:30:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4888473318139,
#   'end': '20:30:00',
#   'discount_until': None,
#   'categories': ['카페디저트', '프랜차이즈', '테이크아웃'],
#   'review_avg': 4.7,
#   'min_order_amount': 12000,
#   'distance': 0.59360636718,
#   'franchise_name': '(주)섹타나인양재지점 / 던킨도너츠',
#   'except_cash': True,
#   'name': '던킨-내방점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/던킨도너츠_20181228_Franchise이미지약정서_crop_200x200_fG79bfM.png',
#   'address': '서울 서초구 방배동 852-16'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 14,
#   'adjusted_delivery_fee': 4400,
#   'is_available_delivery': True,
#   'new_rating': 0.2251996,
#   'app_order': True,
#   'lng': 127.019837040682,
#   'list_pos': 16,
#   'open': True,
#   'id': 477188,
#   'estimated_delivery_time': '29분',
#   'review_count': 306,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 561,
#   'discounts': {'delivery_fee': {'funding': 3000, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210105101758905543_759c74f1750da0e1c460897d7733a3c5_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.495193688217,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '피자양식'],
#   'review_avg': 4.8,
#   'min_order_amount': 20000,
#   'distance': 2.78217653971,
#   'franchise_name': '씨제이푸드빌(주) / 빕스',
#   'except_cash': True,
#   'name': '빕스얌딜리버리-서초점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 305,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '900원', 'basic': '4,400원'},
#   'logo_url': '/media/franchise_logos/빕스_20210105_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하1층 101호 내 22호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 15,
#   'adjusted_delivery_fee': 0,
#   'is_available_delivery': True,
#   'new_rating': 0.2016609,
#   'app_order': True,
#   'lng': 126.9877312,
#   'list_pos': 17,
#   'open': True,
#   'id': 33630,
#   'estimated_delivery_time': '33~43분',
#   'review_count': 582,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 41,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 5000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201211181323617330_6f3535ec40b1fba1fc37be5a0c04d4bb_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO', 'relayo'],
#   'representative_menus': '',
#   'address': '서울 서초구 방배동 758-2 삼호상가 1층 118호',
#   'lat': 37.4966162999325,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '피자양식'],
#   'review_avg': 4.7,
#   'min_order_amount': 20000,
#   'distance': 1.50163243699,
#   'franchise_name': '한국파파존스(주) / 파파존스',
#   'except_cash': False,
#   'name': '파파존스피자-방배점',
#   'phone': '050352588699',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 71,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료'},
#   'logo_url': '/media/franchise_logos/파파존스_20200625_Franchise_crop_200x200.jpg'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 16,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.1865767,
#   'app_order': True,
#   'lng': 126.9962801,
#   'list_pos': 18,
#   'open': True,
#   'id': 309760,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 99,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 648,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201216172414729435_53a051bc3383ad3aa1d4add2ad938c6f_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4828112999307,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['카페디저트', '프랜차이즈'],
#   'review_avg': 4.5,
#   'min_order_amount': 12000,
#   'distance': 0.39133190380000005,
#   'franchise_name': '투썸플레이스주식회사 / 투썸플레이스',
#   'except_cash': True,
#   'name': '투썸플레이스-방배역점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 83,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/투썸플레이스_20200323_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 910-14 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 17,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.1857439,
#   'app_order': True,
#   'lng': 126.996361190021,
#   'list_pos': 19,
#   'open': True,
#   'id': 545162,
#   'estimated_delivery_time': '21분',
#   'review_count': 126,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 1096,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20211108133157085193_b5ad6d48b4f7d9916440efad814ca98d_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '12:30:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4818781258087,
#   'end': '22:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '샌드위치', '카페디저트'],
#   'review_avg': 4.5,
#   'min_order_amount': 8000,
#   'distance': 0.43133558483,
#   'franchise_name': '주식회사골든하인드 / 에그드랍',
#   'except_cash': True,
#   'name': '에그드랍-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '2,900원'},
#   'logo_url': '/media/franchise_logos/에그드랍OD_20211108_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 911-16 911-16 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 18,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.170436,
#   'app_order': True,
#   'lng': 126.983253206562,
#   'list_pos': 20,
#   'open': True,
#   'id': 458334,
#   'estimated_delivery_time': '47~57분',
#   'review_count': 0,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 1069,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 11000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 11000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200618110432510737_df539b0d143725c751cc0fe2863350c8_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4873012630914,
#   'end': '22:30:00',
#   'discount_until': None,
#   'categories': ['피자양식', '프랜차이즈', '테이크아웃', '1인분주문'],
#   'review_avg': 0.0,
#   'min_order_amount': 11000,
#   'distance': 0.87354275489,
#   'franchise_name': '(주)섹타나인양재지점 / PBDELI',
#   'except_cash': True,
#   'name': 'PB델리-방배현대점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/PBDELI_20200602_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 1461 인텔고시원 1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 19,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.1643338,
#   'app_order': True,
#   'lng': 126.985836588694,
#   'list_pos': 21,
#   'open': True,
#   'id': 252710,
#   'estimated_delivery_time': '56~66분',
#   'review_count': 1039,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 71,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 16000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 16000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210315164332919147_ed6739c1b1346c6033574db2f9b0a303_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '12:00:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4923623568624,
#   'end': '23:30:00',
#   'discount_until': None,
#   'categories': ['야식', '치킨', '테이크아웃', '프랜차이즈'],
#   'review_avg': 4.6,
#   'min_order_amount': 16000,
#   'distance': 1.11991640906,
#   'franchise_name': '(주)페리카나 / 페리카나',
#   'except_cash': False,
#   'name': '페리카나-방배본점',
#   'phone': '050712913139',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 891,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/페리카나_20210616_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 789-17 789-17'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 20,
#   'adjusted_delivery_fee': 0,
#   'is_available_delivery': True,
#   'new_rating': 0.1642172,
#   'app_order': True,
#   'lng': 126.993072784527,
#   'list_pos': 22,
#   'open': True,
#   'id': 336027,
#   'estimated_delivery_time': '38~48분',
#   'review_count': 318,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 85,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 6000,
#      'discount_mov': 19900}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210803135635842339_a989b0b91a473801e2db0f91391a3e87_tn.jpg',
#   'reachable': True,
#   'additional_discount': 6000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO', 'relayo'],
#   'representative_menus': '',
#   'address': '서울 서초구 방배동 851-6 태창빌딩 1층 가호',
#   'lat': 37.4892925371193,
#   'end': '22:30:00',
#   'discount_until': None,
#   'categories': ['피자양식', '프랜차이즈'],
#   'review_avg': 4.5,
#   'min_order_amount': 19900,
#   'distance': 0.64842071559,
#   'franchise_name': '한국피자헛유한회사 / 피자헛',
#   'except_cash': False,
#   'name': '피자헛-방배2호점',
#   'phone': '050712992122',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 28,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료'},
#   'logo_url': '/media/franchise_logos/피자헛_20170612_Franchise이미지약정서_crop_200x200.jpg'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 21,
#   'adjusted_delivery_fee': 3900,
#   'is_available_delivery': True,
#   'new_rating': 0.1560712,
#   'app_order': True,
#   'lng': 126.994603640399,
#   'list_pos': 23,
#   'open': True,
#   'id': 287091,
#   'estimated_delivery_time': '27분',
#   'review_count': 442,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 301,
#   'discounts': {'delivery_fee': {'funding': 1900, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 16000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201209174451671994_270baa1a9c7c2ed7e428c255658bbd45_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.5054333512309,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '치킨'],
#   'review_avg': 4.8,
#   'min_order_amount': 16000,
#   'distance': 2.44675516556,
#   'franchise_name': '주식회사한울 / 돈치킨',
#   'except_cash': True,
#   'name': '돈치킨-반포점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 7,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '1,500원', 'basic': '3,900원'},
#   'logo_url': '/media/franchise_logos/돈피자OD_20210203_Franchise_crop_200x200_GjpHoKV_mneMXsS.jpg',
#   'address': '서울 서초구 반포동 2-8 신반포상가 201호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 22,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.1553866,
#   'app_order': True,
#   'lng': 126.98384912789,
#   'list_pos': 24,
#   'open': True,
#   'id': 412563,
#   'estimated_delivery_time': '50~60분',
#   'review_count': 495,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 654,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 0},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609141652474942_28f5298ba9060adba417159b6e431f6b_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4859076399211,
#   'end': '00:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '테이크아웃', '한식', '야식', '찜탕'],
#   'review_avg': 4.9,
#   'min_order_amount': 15000,
#   'distance': 0.7611439735200001,
#   'franchise_name': '(주)놀부 / 흥부찜닭',
#   'except_cash': False,
#   'name': '흥부찜닭by놀부-방배점',
#   'phone': '050718666886',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 493,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/흥부찜닭_20210722_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 23,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.1405696,
#   'app_order': True,
#   'lng': 126.9806025,
#   'list_pos': 25,
#   'open': True,
#   'id': 61311,
#   'estimated_delivery_time': '30~40분',
#   'review_count': 936,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 28,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200408102755524276_d948de5f76247ad7a4310389d32a94ac_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '11:20:00',
#   'is_available_pickup': True,
#   'tags': [],
#   'representative_menus': '',
#   'address': '서울 동작구 사당동 139-63번지 1,2층',
#   'lat': 37.4868015,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['야식', '프랜차이즈', '족발보쌈', '테이크아웃'],
#   'review_avg': 4.6,
#   'min_order_amount': 25000,
#   'distance': 1.0643114741500002,
#   'franchise_name': '(주)원앤원 / 원할머니보쌈',
#   'except_cash': False,
#   'name': '원할머니보쌈족발-이수역점',
#   'phone': '050352563983',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 936,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/원할머니보쌈02_20150716_Franchise이미지약정서_crop_200x200.jpg'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 24,
#   'adjusted_delivery_fee': 1500,
#   'is_available_delivery': True,
#   'new_rating': 0.1374698,
#   'app_order': True,
#   'lng': 126.998381992716,
#   'list_pos': 26,
#   'open': True,
#   'id': 250513,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 330,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 80,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 7000,
#      'discount_mov': 19900}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200319134444642414_4f486eaab1f5064627eaf6a518c11907_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 1,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO', 'relayo'],
#   'representative_menus': '',
#   'address': '서울특별시 서초구 방배동 984-4 미피하우스 984-4 미피하우스 1층',
#   'lat': 37.4813573823629,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '피자양식'],
#   'review_avg': 4.6,
#   'min_order_amount': 19900,
#   'distance': 0.6177742481499999,
#   'franchise_name': '[Brand]미스터피자',
#   'except_cash': False,
#   'name': '미스터피자-방배본점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 238,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '1,500원'},
#   'logo_url': '/media/franchise_logos/미스터피자_20200319_Franchise_crop_200x200.jpg'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 25,
#   'adjusted_delivery_fee': 0,
#   'is_available_delivery': True,
#   'new_rating': 0.1319846,
#   'app_order': True,
#   'lng': 126.999287457132,
#   'list_pos': 27,
#   'open': True,
#   'id': 567462,
#   'estimated_delivery_time': '35~45분',
#   'review_count': 57,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 652,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 5000,
#      'discount_mov': 21900}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210908101636002485_8fbb9bd8825e90cfc24e4da808366799_tn.jpg',
#   'reachable': True,
#   'additional_discount': 5000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '11:30:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'address': '서울 서초구 방배동 985-6 서진빌딩',
#   'lat': 37.481457724664,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '피자양식'],
#   'review_avg': 4.7,
#   'min_order_amount': 21900,
#   'distance': 0.68819026458,
#   'franchise_name': '(주)청오디피케이 / 도미노피자',
#   'except_cash': True,
#   'name': '도미노피자-방배역점',
#   'phone': '050702780760',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료'},
#   'logo_url': '/media/franchise_logos/도미노피자_20190102_Franchise이미지약정서_crop_200x200.jpg'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 26,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.1303217,
#   'app_order': True,
#   'lng': 126.984876617489,
#   'list_pos': 28,
#   'open': True,
#   'id': 253137,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 480,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 7,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 15000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201221182259967766_ea8863c6bc7b22fa56f9f2f4ab382bb1_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '12:30:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'address': '서울 서초구 방배동 767-24 1층',
#   'lat': 37.4940211609975,
#   'end': '23:40:00',
#   'discount_until': None,
#   'categories': ['테이크아웃', '야식', '프랜차이즈', '치킨'],
#   'review_avg': 4.8,
#   'min_order_amount': 13000,
#   'distance': 1.32244793768,
#   'franchise_name': '(주)혜인식품 / 네네치킨',
#   'except_cash': False,
#   'name': '네네치킨-방배본동점',
#   'phone': '050712913555',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 480,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/네네치킨_20200310_Franchise_crop_200x200.jpg'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 27,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.1244457,
#   'app_order': True,
#   'lng': 127.017173601089,
#   'list_pos': 29,
#   'open': True,
#   'id': 565692,
#   'estimated_delivery_time': '56~66분',
#   'review_count': 437,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 10,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 16000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 5000,
#      'discount_mov': 16000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210722133902784138_047561649216af5f8d8e14be8b4901c5_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '12:00:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO', 'relayo'],
#   'representative_menus': '',
#   'lat': 37.488255577743,
#   'end': '23:59:00',
#   'discount_until': None,
#   'categories': ['테이크아웃', '치킨', '프랜차이즈'],
#   'review_avg': 4.6,
#   'min_order_amount': 16000,
#   'distance': 2.28769580689,
#   'franchise_name': '(주)멕시카나 / 멕시카나치킨',
#   'except_cash': False,
#   'name': '멕시카나-서초교대점',
#   'phone': '050353719019',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/멕시카나_20201027_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 서초동 1627-5 교대빌딩 1627-5 교대빌딩 1층 A동 102호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
# ...
#   'name': '훈남순대국',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '3,400원', 'basic': '3,900원'},
#   'logo_url': '/media/restaurant_logos/스탁_20190801_DHK촬영_순대국_Side02_300x300_B4VjYw6.jpg',
#   'address': '서울특별시 관악구 봉천동 1655-50 1층 1호(봉천동)'},
#  {'phone_order': True,
#   'section_pos': 5,
#   'adjusted_delivery_fee': 1500,
#   'is_available_delivery': True,
#   'new_rating': 0.4299983,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.977323445093,
#   'list_pos': 51,
#   'open': True,
#   'id': 424030,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 1361,
#   'discount_from': '2021-11-10T12:00:00',
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210513130000000000_820861c6ed867fadaed34597dcbcde72_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4835715285553,
#   'end': '09:59:00',
#   'discount_until': '2021-11-10T23:59:59.999999',
#   'categories': ['야식', '치킨', '테이크아웃'],
#   'review_avg': 4.8,
#   'min_order_amount': 10800,
#   'distance': 1.28961531244,
#   'minimum_pickup_minutes': 10,
#   'except_cash': False,
#   'name': '맛카오치킨',
#   'phone': '050352848066',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1106,
#   'discount_percent': 5,
#   'delivery_fee_to_display': {'basic': '1,500원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20200310_424030_맛카오치킨_대표사진_300x300.jpg',
#   'address': '서울 동작구 사당동 1001-32 1층'},
#  {'phone_order': True,
#   'section_pos': 6,
#   'adjusted_delivery_fee': 0,
#   'is_available_delivery': True,
#   'new_rating': 0.6336301,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.9758141,
#   'list_pos': 52,
#   'open': True,
#   'id': 243115,
#   'estimated_delivery_time': '40~50분',
#   'review_count': 4287,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 3,
#   'discounts': {'additional': {'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201214171955319908_d9bc449aca19df9bb08f0b1490d9d460_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 40,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO', 'relayo', 'excellent'],
#   'representative_menus': '',
#   'lat': 37.482356,
#   'end': '23:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '피자양식', '테이크아웃'],
#   'review_avg': 4.9,
#   'min_order_amount': 15900,
#   'distance': 1.42878452413,
#   'franchise_name': '(주)반올림피자샵 / 피자샵',
#   'except_cash': False,
#   'name': '반올림피자샵-사당방배점',
#   'phone': '050712903212',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1331,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료'},
#   'logo_url': '/media/franchise_logos/피자샵_20200303_Franchise_crop_200x200.jpg',
#   'address': '서울 동작구 사당동 321-103 1층'},
#  {'phone_order': False,
#   'section_pos': 7,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.5795212,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.983134124098,
#   'list_pos': 53,
#   'open': True,
#   'id': 239906,
#   'estimated_delivery_time': '21분',
#   'review_count': 1094,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 900, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210728104439423527_fbc5df0f659cb541b94056cacc841c14_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '17:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4882560769312,
#   'end': '20:30:00',
#   'discount_until': None,
#   'categories': ['중식'],
#   'review_avg': 4.5,
#   'min_order_amount': 10000,
#   'distance': 0.9378578538100001,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '강릉교동짬뽕-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '1,500원', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20210805_239906_강릉교동짬뽕-방배점_대표사진_300x300.jpg',
#   'address': '서울특별시 서초구 방배동 1847 대신교회 1847 대신교회 1층'},
#  {'phone_order': True,
#   'section_pos': 8,
#   'adjusted_delivery_fee': 0,
#   'is_available_delivery': True,
#   'new_rating': 0.563945,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.9832261,
#   'list_pos': 54,
#   'open': True,
#   'id': 29011,
#   'estimated_delivery_time': '39~49분',
#   'review_count': 2400,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210419110000000000_5a65485d186dbf97e19c3857ac56636d_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4872472999312,
#   'end': '20:30:00',
#   'discount_until': None,
#   'categories': ['중식'],
#   'review_avg': 4.4,
#   'min_order_amount': 9000,
#   'distance': 0.87278507803,
#   'minimum_pickup_minutes': 0,
#   'except_cash': False,
#   'name': '황궁쟁반짜장-서경',
#   'phone': '050352569049',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 3,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료'},
#   'logo_url': '/media/restaurant_logos/짜장면01_20120524_FoodAD_crop_200x200_32.jpg',
#   'address': '서울 서초구 방배4동 1461'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 9,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': -0.2846922,
#   'app_order': True,
#   'lng': 126.980358263752,
#   'list_pos': 55,
#   'open': True,
#   'id': 1024089,
#   'estimated_delivery_time': '23분',
#   'review_count': 3,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20211101172834808848_44644d2ccd90c788cadcc2eea33ee410_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': True,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.476008592048,
#   'end': '20:30:00',
#   'discount_until': None,
#   'categories': ['피자양식', '일식돈까스', '한식'],
#   'review_avg': 4.3,
#   'min_order_amount': 12000,
#   'distance': 1.3205642753300002,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '미찬돈까스&파스타',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 3,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20211025_1024089_미찬돈까스n파스타_대표사진_300x300.jpg',
#   'address': '서울특별시 관악구 남현동 1060-18 범평빌딩 지하1층'},
#  {'phone_order': True,
#   'section_pos': 10,
#   'adjusted_delivery_fee': 1000,
#   'is_available_delivery': True,
#   'new_rating': 0.3078306,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.983067457484,
#   'list_pos': 56,
#   'open': True,
#   'id': 503492,
#   'estimated_delivery_time': '38~48분',
#   'review_count': 986,
#   'discount_from': '2021-11-10T11:45:00',
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 4,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181018163336282782_ef463ea2ae10afbec258e566e2077e8b_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4906982793625,
#   'end': '22:30:00',
#   'discount_until': '2021-11-10T21:44:59.999999',
#   'categories': ['테이크아웃', '프랜차이즈', '피자양식'],
#   'review_avg': 4.9,
#   'min_order_amount': 15000,
#   'distance': 1.11706576179,
#   'franchise_name': '(주)7번가사람들 / 7번가피자',
#   'except_cash': False,
#   'name': '7번가피자-방배사당점',
#   'phone': '050352938856',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 942,
#   'discount_percent': 10,
#   'delivery_fee_to_display': {'basic': '1,000원'},
#   'logo_url': '/media/franchise_logos/7번가피자_20210326_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 2253 1층'},
#  {'phone_order': True,
#   'section_pos': 11,
#   'adjusted_delivery_fee': 1000,
#   'is_available_delivery': True,
#   'new_rating': 0.537734,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.978385413834,
#   'list_pos': 57,
#   'open': True,
#   'id': 528238,
#   'estimated_delivery_time': '55~65분',
#   'review_count': 1582,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 821,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 14900},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 14900}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210721181909058631_57af6ae91ef1a7d424e1eeae7bad38c2_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': True,
#   'tags': ['excellent'],
#   'representative_menus': '',
#   'lat': 37.4849343277204,
#   'end': '00:50:00',
#   'discount_until': None,
#   'categories': ['피자양식', '프랜차이즈', '테이크아웃'],
#   'review_avg': 4.9,
#   'min_order_amount': 15900,
#   'distance': 1.20602973724,
#   'franchise_name': '(주)비에스비푸드 / 청년피자',
#   'except_cash': False,
#   'name': '청년피자-사당방배점',
#   'phone': '050352965404',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 706,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '1,000원'},
#   'logo_url': '/media/franchise_logos/청년피자_20210621_Franchise_crop_200x200_Dxc08kl.jpg',
#   'address': '서울특별시 동작구 사당동 150-13 150-13 1층'},
#  {'phone_order': False,
#   'section_pos': 12,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.5297729,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.994540317825,
#   'list_pos': 58,
#   'open': True,
#   'id': 569027,
#   'estimated_delivery_time': '13분',
#   'review_count': 234,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 1900, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210517181040721688_98c469d002ee0e339def4e079e8c7b39_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '11:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4850798399444,
#   'end': '21:00:00',
#   'discount_until': None,
#   'categories': ['분식'],
#   'review_avg': 4.8,
#   'min_order_amount': 12000,
#   'distance': 0.28697051738,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '홍미단블랙딜리버리',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '500원', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/DHK촬영_20210520_569027_홍미단블랙딜리버리_대표사진_300x300_xVseQ4a.jpg',
#   'address': '서울 서초구 방배동 925-19 1층'},
#  {'phone_order': False,
#   'section_pos': 13,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.5181116,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.983402953314,
#   'list_pos': 59,
#   'open': True,
#   'id': 574509,
#   'estimated_delivery_time': '19분',
#   'review_count': 175,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 2900, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210720103514843292_3f0009cc923fdb0476bc4eeddcd0f492_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4874676953048,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['한식', '프랜차이즈', '1인분주문', '고기구이'],
#   'review_avg': 4.6,
#   'min_order_amount': 8900,
#   'distance': 0.8711246434800001,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '덮다-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 175,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '무료', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20210720_574509_덮다-방배점_대표사진_300x300.jpg',
#   'address': '서울 서초구 방배동 1458 2층'},
#  {'phone_order': True,
#   'section_pos': 14,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.3043536,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 127.01983358,
#   'list_pos': 60,
#   'open': True,
#   'id': 487219,
#   'estimated_delivery_time': '50~60분',
#   'review_count': 1171,
#   'discount_from': '2021-11-10T18:00:00',
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 34,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210928141110387017_e8b104f2e9e7af49295a78df14ee7d1d_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '12:58:00',
#   'is_available_pickup': True,
#   'tags': ['excellent'],
#   'representative_menus': '',
#   'lat': 37.4952002356867,
#   'end': '02:30:00',
#   'discount_until': '2021-11-10T23:59:59.999999',
#   'categories': ['프랜차이즈', '치킨', '테이크아웃', '야식'],
#   'review_avg': 4.8,
#   'min_order_amount': 16000,
#   'distance': 2.78224577834,
#   'franchise_name': '(주)컬투에프앤비 / 컬투치킨',
#   'except_cash': False,
#   'name': '컬투치킨-서초1호점',
#   'phone': '050352921309',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1020,
#   'discount_percent': 5,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/컬투치킨_20180309_Franchise이미지약정서_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 9호'}]

# %%
# list comprehension

# 담기로 한 정보 : 매장명, 평점평균, 리뷰수, 사장님답글수, 할인정보, 배달료정보, 최소주문금액

result = [
    {
        "매장명":el.get('name').strip(),
        "평점평균":el.get('review_avg'),
        "리뷰수":el.get('review_count'),
        "사장님답글수":el.get('owner_reply_count'),
        "최소주문금액":el.get('min_order_amount'),
    }
    for el in ygy_data['restaurants']
]

result
# Out:
# [{'매장명': '김가네-방배본동점', '평점평균': 4.6, '리뷰수': 1375, '사장님답글수': 51, '최소주문금액': 15000},
#  {'매장명': '텍사스바베큐-사당점', '평점평균': 4.9, '리뷰수': 18, '사장님답글수': 4, '최소주문금액': 20000},
#  {'매장명': '청년피자-사당방배점',
#   '평점평균': 4.9,
#   '리뷰수': 1582,
#   '사장님답글수': 706,
#   '최소주문금액': 15900},
#  {'매장명': '후라이드참잘하는집-사당점',
#   '평점평균': 4.7,
#   '리뷰수': 4082,
#   '사장님답글수': 470,
#   '최소주문금액': 14000},
#  {'매장명': '두마리찜닭두찜-서초방배점',
#   '평점평균': 4.9,
#   '리뷰수': 886,
#   '사장님답글수': 768,
#   '최소주문금액': 16000},
#  {'매장명': '코리엔탈깻잎두마리치킨-낙성대점',
#   '평점평균': 4.9,
#   '리뷰수': 1082,
#   '사장님답글수': 945,
#   '최소주문금액': 12000},
#  {'매장명': '놀부보쌈족발-서초점',
#   '평점평균': 4.6,
#   '리뷰수': 711,
#   '사장님답글수': 693,
#   '최소주문금액': 12000},
#  {'매장명': '미스터보쌈족발-낙성대점',
#   '평점평균': 4.8,
#   '리뷰수': 1410,
#   '사장님답글수': 14,
#   '최소주문금액': 18900},
#  {'매장명': '7번가피자-방배사당점',
#   '평점평균': 4.9,
#   '리뷰수': 986,
#   '사장님답글수': 942,
#   '최소주문금액': 15000},
#  {'매장명': '컬투치킨-서초1호점',
#   '평점평균': 4.8,
#   '리뷰수': 1171,
#   '사장님답글수': 1020,
#   '최소주문금액': 16000},
#  {'매장명': '쫄면주는삼겹본능by놀부-방배점',
#   '평점평균': 4.8,
#   '리뷰수': 968,
#   '사장님답글수': 959,
#   '최소주문금액': 17000},
#  {'매장명': '또래오래-서초방배점', '평점평균': 4.6, '리뷰수': 1354, '사장님답글수': 0, '최소주문금액': 15000},
#  {'매장명': '아웃백-서초점', '평점평균': 4.7, '리뷰수': 1179, '사장님답글수': 1177, '최소주문금액': 20000},
#  {'매장명': '버거킹-방배점', '평점평균': 4.7, '리뷰수': 444, '사장님답글수': 199, '최소주문금액': 8000},
#  {'매장명': '던킨-내방점', '평점평균': 4.7, '리뷰수': 355, '사장님답글수': 1, '최소주문금액': 12000},
#  {'매장명': '빕스얌딜리버리-서초점',
#   '평점평균': 4.8,
#   '리뷰수': 306,
#   '사장님답글수': 305,
#   '최소주문금액': 20000},
#  {'매장명': '파파존스피자-방배점', '평점평균': 4.7, '리뷰수': 582, '사장님답글수': 71, '최소주문금액': 20000},
#  {'매장명': '투썸플레이스-방배역점', '평점평균': 4.5, '리뷰수': 99, '사장님답글수': 83, '최소주문금액': 12000},
#  {'매장명': '에그드랍-방배점', '평점평균': 4.5, '리뷰수': 126, '사장님답글수': 0, '최소주문금액': 8000},
#  {'매장명': 'PB델리-방배현대점', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 11000},
#  {'매장명': '페리카나-방배본점',
#   '평점평균': 4.6,
#   '리뷰수': 1039,
#   '사장님답글수': 891,
#   '최소주문금액': 16000},
#  {'매장명': '피자헛-방배2호점', '평점평균': 4.5, '리뷰수': 318, '사장님답글수': 28, '최소주문금액': 19900},
#  {'매장명': '돈치킨-반포점', '평점평균': 4.8, '리뷰수': 442, '사장님답글수': 7, '최소주문금액': 16000},
#  {'매장명': '흥부찜닭by놀부-방배점',
#   '평점평균': 4.9,
#   '리뷰수': 495,
#   '사장님답글수': 493,
#   '최소주문금액': 15000},
#  {'매장명': '원할머니보쌈족발-이수역점',
#   '평점평균': 4.6,
#   '리뷰수': 936,
#   '사장님답글수': 936,
#   '최소주문금액': 25000},
#  {'매장명': '미스터피자-방배본점',
#   '평점평균': 4.6,
#   '리뷰수': 330,
#   '사장님답글수': 238,
#   '최소주문금액': 19900},
#  {'매장명': '도미노피자-방배역점', '평점평균': 4.7, '리뷰수': 57, '사장님답글수': 0, '최소주문금액': 21900},
#  {'매장명': '네네치킨-방배본동점',
#   '평점평균': 4.8,
#   '리뷰수': 480,
#   '사장님답글수': 480,
#   '최소주문금액': 13000},
#  {'매장명': '멕시카나-서초교대점', '평점평균': 4.6, '리뷰수': 437, '사장님답글수': 1, '최소주문금액': 16000},
#  {'매장명': '빅스타피자-사당방배점', '평점평균': 4.3, '리뷰수': 46, '사장님답글수': 0, '최소주문금액': 13900},
#  {'매장명': '돈까스퐁당떡볶이공수간-방배점',
#   '평점평균': 4.7,
#   '리뷰수': 269,
#   '사장님답글수': 269,
#   '최소주문금액': 17000},
#  {'매장명': '족보잇는국밥&밀면-방배점',
#   '평점평균': 5.0,
#   '리뷰수': 74,
#   '사장님답글수': 0,
#   '최소주문금액': 15000},
#  {'매장명': '호치킨-이수점', '평점평균': 4.8, '리뷰수': 60, '사장님답글수': 0, '최소주문금액': 13900},
#  {'매장명': '호식이두마리치킨-방배1호점',
#   '평점평균': 4.8,
#   '리뷰수': 36,
#   '사장님답글수': 0,
#   '최소주문금액': 14000},
#  {'매장명': '떡참떡볶이참잘하는집-서초방배점',
#   '평점평균': 4.8,
#   '리뷰수': 30,
#   '사장님답글수': 0,
#   '최소주문금액': 12000},
#  {'매장명': '뚜레쥬르-상도래미안점',
#   '평점평균': 4.8,
#   '리뷰수': 218,
#   '사장님답글수': 100,
#   '최소주문금액': 12000},
#  {'매장명': '세븐일레븐-내방중앙점', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 10000},
#  {'매장명': '맘스터치-이수점', '평점평균': 4.7, '리뷰수': 109, '사장님답글수': 80, '최소주문금액': 12000},
#  {'매장명': '파스쿠찌-이수역점', '평점평균': 4.6, '리뷰수': 171, '사장님답글수': 170, '최소주문금액': 12000},
#  {'매장명': '놀부부대찌개-사당점', '평점평균': 4.6, '리뷰수': 249, '사장님답글수': 44, '최소주문금액': 19000},
#  {'매장명': 'CU-방배제일점', '평점평균': 4.6, '리뷰수': 10, '사장님답글수': 0, '최소주문금액': 10000},
#  {'매장명': '돈피자-반포점', '평점평균': 4.7, '리뷰수': 3, '사장님답글수': 0, '최소주문금액': 16000},
#  {'매장명': '고피자-강남점', '평점평균': 4.5, '리뷰수': 40, '사장님답글수': 38, '최소주문금액': 14900},
#  {'매장명': '또봉이통닭-서초점', '평점평균': 4.5, '리뷰수': 249, '사장님답글수': 10, '최소주문금액': 13800},
#  {'매장명': '찜꽁찜닭-서래마을점', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 10500},
#  {'매장명': '곱떡치떡-서래마을점', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 10500},
#  {'매장명': '동원-방배점', '평점평균': 4.5, '리뷰수': 1895, '사장님답글수': 1647, '최소주문금액': 10000},
#  {'매장명': '구백냥곱창-이수직영점', '평점평균': 4.9, '리뷰수': 543, '사장님답글수': 6, '최소주문금액': 10500},
#  {'매장명': '만다린-방배점', '평점평균': 4.6, '리뷰수': 1468, '사장님답글수': 0, '최소주문금액': 11000},
#  {'매장명': '훈남순대국', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 15000},
#  {'매장명': '맛카오치킨', '평점평균': 4.8, '리뷰수': 1361, '사장님답글수': 1106, '최소주문금액': 10800},
#  {'매장명': '반올림피자샵-사당방배점',
#   '평점평균': 4.9,
#   '리뷰수': 4287,
#   '사장님답글수': 1331,
#   '최소주문금액': 15900},
#  {'매장명': '강릉교동짬뽕-방배점', '평점평균': 4.5, '리뷰수': 1094, '사장님답글수': 0, '최소주문금액': 10000},
#  {'매장명': '황궁쟁반짜장-서경', '평점평균': 4.4, '리뷰수': 2400, '사장님답글수': 3, '최소주문금액': 9000},
#  {'매장명': '미찬돈까스&파스타', '평점평균': 4.3, '리뷰수': 3, '사장님답글수': 3, '최소주문금액': 12000},
#  {'매장명': '7번가피자-방배사당점',
#   '평점평균': 4.9,
#   '리뷰수': 986,
#   '사장님답글수': 942,
#   '최소주문금액': 15000},
#  {'매장명': '청년피자-사당방배점',
#   '평점평균': 4.9,
#   '리뷰수': 1582,
#   '사장님답글수': 706,
#   '최소주문금액': 15900},
#  {'매장명': '홍미단블랙딜리버리', '평점평균': 4.8, '리뷰수': 234, '사장님답글수': 0, '최소주문금액': 12000},
#  {'매장명': '덮다-방배점', '평점평균': 4.6, '리뷰수': 175, '사장님답글수': 175, '최소주문금액': 8900},
#  {'매장명': '컬투치킨-서초1호점',
#   '평점평균': 4.8,
#   '리뷰수': 1171,
#   '사장님답글수': 1020,
#   '최소주문금액': 16000}]

# %%
df = pd.DataFrame(result)
df.head(10)  # 인덱스 순서 상위10개
# Out:
#                 매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 0         김가네-방배본동점   4.6  1375      51   15000
# 1        텍사스바베큐-사당점   4.9    18       4   20000
# 2        청년피자-사당방배점   4.9  1582     706   15900
# 3     후라이드참잘하는집-사당점   4.7  4082     470   14000
# 4     두마리찜닭두찜-서초방배점   4.9   886     768   16000
# 5  코리엔탈깻잎두마리치킨-낙성대점   4.9  1082     945   12000
# 6        놀부보쌈족발-서초점   4.6   711     693   12000
# 7      미스터보쌈족발-낙성대점   4.8  1410      14   18900
# 8       7번가피자-방배사당점   4.9   986     942   15000
# 9        컬투치킨-서초1호점   4.8  1171    1020   16000

# %%
# 리뷰수 기준 상위 20개 가게
df.sort_values('리뷰수', ascending=False)[:20]
# Out:
#                  매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 51      반올림피자샵-사당방배점   4.9  4287    1331   15900
# 3      후라이드참잘하는집-사당점   4.7  4082     470   14000
# 53         황궁쟁반짜장-서경   4.4  2400       3    9000
# 46            동원-방배점   4.5  1895    1647   10000
# 2         청년피자-사당방배점   4.9  1582     706   15900
# 56        청년피자-사당방배점   4.9  1582     706   15900
# 48           만다린-방배점   4.6  1468       0   11000
# 7       미스터보쌈족발-낙성대점   4.8  1410      14   18900
# 0          김가네-방배본동점   4.6  1375      51   15000
# 50             맛카오치킨   4.8  1361    1106   10800
# 11        또래오래-서초방배점   4.6  1354       0   15000
# 12           아웃백-서초점   4.7  1179    1177   20000
# 59        컬투치킨-서초1호점   4.8  1171    1020   16000
# 9         컬투치킨-서초1호점   4.8  1171    1020   16000
# 52        강릉교동짬뽕-방배점   4.5  1094       0   10000
# 5   코리엔탈깻잎두마리치킨-낙성대점   4.9  1082     945   12000
# 20         페리카나-방배본점   4.6  1039     891   16000
# 55       7번가피자-방배사당점   4.9   986     942   15000
# 8        7번가피자-방배사당점   4.9   986     942   15000
# 10  쫄면주는삼겹본능by놀부-방배점   4.8   968     959   17000

# %%
# 평점평균 기준 상위 20개 가게
df.sort_values('평점평균', ascending=False)[:20]
# Out:
#                  매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 31     족보잇는국밥&밀면-방배점   5.0    74       0   15000
# 1         텍사스바베큐-사당점   4.9    18       4   20000
# 2         청년피자-사당방배점   4.9  1582     706   15900
# 4      두마리찜닭두찜-서초방배점   4.9   886     768   16000
# 5   코리엔탈깻잎두마리치킨-낙성대점   4.9  1082     945   12000
# 56        청년피자-사당방배점   4.9  1582     706   15900
# 23      흥부찜닭by놀부-방배점   4.9   495     493   15000
# 8        7번가피자-방배사당점   4.9   986     942   15000
# 55       7번가피자-방배사당점   4.9   986     942   15000
# 51      반올림피자샵-사당방배점   4.9  4287    1331   15900
# 47       구백냥곱창-이수직영점   4.9   543       6   10500
# 35       뚜레쥬르-상도래미안점   4.8   218     100   12000
# 22           돈치킨-반포점   4.8   442       7   16000
# 32           호치킨-이수점   4.8    60       0   13900
# 33    호식이두마리치킨-방배1호점   4.8    36       0   14000
# 34  떡참떡볶이참잘하는집-서초방배점   4.8    30       0   12000
# 59        컬투치킨-서초1호점   4.8  1171    1020   16000
# 15       빕스얌딜리버리-서초점   4.8   306     305   20000
# 27        네네치킨-방배본동점   4.8   480     480   13000
# 10  쫄면주는삼겹본능by놀부-방배점   4.8   968     959   17000

# %%
# 근데 평점 평균으로는 리뷰수가 적은 가게도 높게 나오기 때문에 신뢰할만한 표본으로 보기 어렵다
# 뭔가 맛집 반영이 제대로 되지 않는거 같다.
# 최소 리뷰수 300이 넘는 가게만 모아서 따로 순위를 내보자

# %%
review_count_over300 = df[df['리뷰수']>= 300]
review_count_over300[:20]
# Out:
#                  매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 0          김가네-방배본동점   4.6  1375      51   15000
# 2         청년피자-사당방배점   4.9  1582     706   15900
# 3      후라이드참잘하는집-사당점   4.7  4082     470   14000
# 4      두마리찜닭두찜-서초방배점   4.9   886     768   16000
# 5   코리엔탈깻잎두마리치킨-낙성대점   4.9  1082     945   12000
# 6         놀부보쌈족발-서초점   4.6   711     693   12000
# 7       미스터보쌈족발-낙성대점   4.8  1410      14   18900
# 8        7번가피자-방배사당점   4.9   986     942   15000
# 9         컬투치킨-서초1호점   4.8  1171    1020   16000
# 10  쫄면주는삼겹본능by놀부-방배점   4.8   968     959   17000
# 11        또래오래-서초방배점   4.6  1354       0   15000
# 12           아웃백-서초점   4.7  1179    1177   20000
# 13           버거킹-방배점   4.7   444     199    8000
# 14            던킨-내방점   4.7   355       1   12000
# 15       빕스얌딜리버리-서초점   4.8   306     305   20000
# 16        파파존스피자-방배점   4.7   582      71   20000
# 20         페리카나-방배본점   4.6  1039     891   16000
# 21         피자헛-방배2호점   4.5   318      28   19900
# 22           돈치킨-반포점   4.8   442       7   16000
# 23      흥부찜닭by놀부-방배점   4.9   495     493   15000

# %%
review_count_over300 = review_count_over300.sort_values('평점평균', ascending=False).reset_index(drop=True)
review_count_over300.index += 1
review_count_over300[:20]
# Out:
#                  매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 1      두마리찜닭두찜-서초방배점   4.9   886     768   16000
# 2   코리엔탈깻잎두마리치킨-낙성대점   4.9  1082     945   12000
# 3         청년피자-사당방배점   4.9  1582     706   15900
# 4       흥부찜닭by놀부-방배점   4.9   495     493   15000
# 5        7번가피자-방배사당점   4.9   986     942   15000
# 6         청년피자-사당방배점   4.9  1582     706   15900
# 7        7번가피자-방배사당점   4.9   986     942   15000
# 8        구백냥곱창-이수직영점   4.9   543       6   10500
# 9       반올림피자샵-사당방배점   4.9  4287    1331   15900
# 10        컬투치킨-서초1호점   4.8  1171    1020   16000
# 11       빕스얌딜리버리-서초점   4.8   306     305   20000
# 12             맛카오치킨   4.8  1361    1106   10800
# 13           돈치킨-반포점   4.8   442       7   16000
# 14        네네치킨-방배본동점   4.8   480     480   13000
# 15  쫄면주는삼겹본능by놀부-방배점   4.8   968     959   17000
# 16        컬투치킨-서초1호점   4.8  1171    1020   16000
# 17      미스터보쌈족발-낙성대점   4.8  1410      14   18900
# 18            던킨-내방점   4.7   355       1   12000
# 19        파파존스피자-방배점   4.7   582      71   20000
# 20           버거킹-방배점   4.7   444     199    8000

# %%
# 리뷰수 최소 300 이상인 가게 중 평점 높은 가게 top 10
result1 = review_count_over300[:10]
result1
# Out:
#                  매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 1      두마리찜닭두찜-서초방배점   4.9   886     768   16000
# 2   코리엔탈깻잎두마리치킨-낙성대점   4.9  1082     945   12000
# 3         청년피자-사당방배점   4.9  1582     706   15900
# 4       흥부찜닭by놀부-방배점   4.9   495     493   15000
# 5        7번가피자-방배사당점   4.9   986     942   15000
# 6         청년피자-사당방배점   4.9  1582     706   15900
# 7        7번가피자-방배사당점   4.9   986     942   15000
# 8        구백냥곱창-이수직영점   4.9   543       6   10500
# 9       반올림피자샵-사당방배점   4.9  4287    1331   15900
# 10        컬투치킨-서초1호점   4.8  1171    1020   16000
