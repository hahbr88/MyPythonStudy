# %% [markdown]
# # 서울특별시 방배동의 요기요 식당 정보
# - 매장명, 평점평균, 리뷰수, 사장님답글수, 최소주문금액 가져오기

# %%
import requests
import pandas as pd
import numpy as np
import os

# %%
url = 'https://www.yogiyo.co.kr/api/v1/restaurants-geo/?items=60&lat=37.4835309976812&lng=126.991938810326&order=rank&page=0&search='
response = requests.get(url)
print(response)  # 400 에러 Bad Request
print(response.text) # 에러의 내용
# Out:
# <Response [400]>
# [["error", "API key or secret is missing"]]

# %%
# 400 에러 가 뜬다
# 접근이 막혀있다.
# 에러메세지는 API key or secret is missing

# %% [markdown]
# 웹크롤러 같은 봇이 함부로 자사의 사이트 정보를 크롤링 하지 못하게 필터링 하는 다양한 방법이 있는데
# 그중에 하나가 request 시 추가 되는 header 정보를 사용하는 방법이다
# 1. header 정보를 통해 정상적인 request 인지 확인하거나
# 2. header 에 특수한 정보를 넣어서 그 정보가 있는 경우에만 정상적으로 response 한다든가

# %%
# API key 와 secret을 찾아서 header 에 추가해보자
# 근데 API key를 어떻게 찾을까????
# 우리에겐 구글 크롬이 있다

# %%
# 그 전에 파이썬으로 request 를 할때 헤더는 어떻게 생겼는지 한번 보도록 하자

py_header = requests.get('https://httpbin.org/headers')  # header를 볼수 있는 url
print(py_header.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-618dc98d-5dbc165a6cd7fbc23aa15155"
#   }
# }

# %%
# 헤더에 인위적으로 api 키를 추가해서 요기요 서버를 한번 속여보자

# %%
#headers 정보 추가
headers = {
  "X-ApiKey": "iphoneap",  # API key
  "X-ApiSecret": "fe5183cc3dea12bd0ce299cf110a75a2",  # secret
  'User-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36"  # 크롬에서 리퀘스트 한척 하기
}

# %%
response = requests.get(url, headers=headers) # 헤더 정보 수정&추가
print(response)

# ↓↓↓↓ 200 떳따!
# Out:
# <Response [200]>

# %%
# json() 함수로 json 으로 변환하여 새로운 변수에 담는다.
ygy_data =  response.json()
ygy_data
# Out:
# {'pagination': {'per_page': 60,
#   'total_objects': 2342,
#   'current_page': 0,
#   'total_pages': 40},
#  'restaurants': [{'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 1,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.2521561,
#    'app_order': True,
#    'lng': 126.9860396,
#    'list_pos': 1,
#    'open': True,
#    'id': 54915,
#    'estimated_delivery_time': '25~35분',
#    'review_count': 1375,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'superlist',
#    'restaurant_type': 'food',
#    'franchise_id': 82,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181004182813010545_d61c21551fb145915b554bc893ffe4f5_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': '주식회사김가네 / 김가네',
#    'thumbnail_message': '',
#    'begin': '09:30:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.49387,
#    'end': '20:20:00',
#    'discount_until': None,
#    'categories': ['분식', '한식', '프랜차이즈'],
#    'review_avg': 4.6,
#    'min_order_amount': 15000,
#    'distance': 1.26198076014,
#    'minimum_pickup_minutes': 0,
#    'except_cash': False,
#    'name': '김가네-방배본동점',
#    'phone': '050352561515',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 51,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/김가네_20210114_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 778-8'},
#   {'phone_order': True,
#    'free_delivery_threshold': 45000,
#    'section_pos': 1,
#    'adjusted_delivery_fee': 1900,
#    'is_available_delivery': True,
#    'new_rating': 0.3638203,
#    'app_order': True,
#    'lng': 126.994658186875,
#    'list_pos': 2,
#    'open': True,
#    'id': 502995,
#    'estimated_delivery_time': '37~47분',
#    'review_count': 896,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 379,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 6000,
#       'discount_mov': 18800},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 6000,
#       'discount_mov': 18800}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210907135553365328_005b0b30e6d7cf00336014679aea181c_tn.jpg',
#    'reachable': True,
#    'additional_discount': 6000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4826159849125,
#    'end': '02:00:00',
#    'discount_until': None,
#    'categories': ['한식', '찜탕', '테이크아웃', '프랜차이즈'],
#    'review_avg': 4.9,
#    'min_order_amount': 16000,
#    'distance': 0.26062970442,
#    'franchise_name': '주식회사기영에프앤비 / 두찜',
#    'except_cash': False,
#    'name': '두마리찜닭두찜-서초방배점',
#    'phone': '050352938520',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 786,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료~1,900원'},
#    'logo_url': '/media/franchise_logos/두찜_20191219_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 922-24 922-24 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 2,
#    'adjusted_delivery_fee': 3400,
#    'is_available_delivery': True,
#    'new_rating': 0.309344,
#    'app_order': True,
#    'lng': 127.008321356362,
#    'list_pos': 3,
#    'open': True,
#    'id': 348355,
#    'estimated_delivery_time': '20분',
#    'review_count': 711,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 24,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201223142237116456_27c175f00c0a134b968bbd9b9d14f353_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4915466145201,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '족발보쌈'],
#    'review_avg': 4.6,
#    'min_order_amount': 12000,
#    'distance': 1.69816528699,
#    'franchise_name': '(주)놀부 / 놀부보쌈',
#    'except_cash': True,
#    'name': '놀부보쌈족발-서초점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 693,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '2,900원', 'basic': '3,400원'},
#    'logo_url': '/media/franchise_logos/놀부보쌈_20201223_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1542-1 지하1층 비18,19호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 3,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.304946,
#    'app_order': True,
#    'lng': 127.01983358,
#    'list_pos': 4,
#    'open': True,
#    'id': 487219,
#    'estimated_delivery_time': '52~62분',
#    'review_count': 1172,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 34,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 3000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210928141110387017_e8b104f2e9e7af49295a78df14ee7d1d_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '10:30:00',
#    'is_available_pickup': True,
#    'tags': ['excellent'],
#    'representative_menus': '',
#    'lat': 37.4952002356867,
#    'end': '02:30:00',
#    'discount_until': None,
#    'categories': ['치킨', '프랜차이즈', '야식', '테이크아웃'],
#    'review_avg': 4.8,
#    'min_order_amount': 16000,
#    'distance': 2.78224577834,
#    'franchise_name': '(주)컬투에프앤비 / 컬투치킨',
#    'except_cash': False,
#    'name': '컬투치킨-서초1호점',
#    'phone': '050352921309',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1020,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/컬투치킨_20180309_Franchise이미지약정서_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 9호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 4,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.2868763,
#    'app_order': True,
#    'lng': 126.98384912789,
#    'list_pos': 5,
#    'open': True,
#    'id': 412564,
#    'estimated_delivery_time': '44~54분',
#    'review_count': 969,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 548,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 0},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142552546157_f0b60b578881144774d34ceb4d0785eb_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4859076399211,
#    'end': '00:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '고기구이', '야식', '한식', '테이크아웃'],
#    'review_avg': 4.8,
#    'min_order_amount': 17000,
#    'distance': 0.7611439735200001,
#    'franchise_name': '(주)놀부 / 쫄면주는삼겹본능',
#    'except_cash': False,
#    'name': '쫄면주는삼겹본능by놀부-방배점',
#    'phone': '050718667053',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 959,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/쫄면주는삼겹본능_20210722_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 5,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.2485344,
#    'app_order': True,
#    'lng': 126.999144987723,
#    'list_pos': 6,
#    'open': True,
#    'id': 282337,
#    'estimated_delivery_time': '58~68분',
#    'review_count': 386,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 475,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 12000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 12000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20191224184656261511_b805645605e9421d51b14065d899f0e4_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4797357992263,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '카페디저트', '테이크아웃'],
#    'review_avg': 4.7,
#    'min_order_amount': 12000,
#    'distance': 0.76315974389,
#    'franchise_name': '(주)섹타나인양재지점 / 파리바게뜨',
#    'except_cash': True,
#    'name': '파리바게뜨-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 67,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/파리바게뜨_20180712_Franchise이미지약정서_crop_200x200_s6Zm07l.jpg',
#    'address': '서울 서초구 방배동 1022-1 우진빌딩 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 13000,
#    'section_pos': 6,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.2311734,
#    'app_order': True,
#    'lng': 126.994844496436,
#    'list_pos': 7,
#    'open': True,
#    'id': 327229,
#    'estimated_delivery_time': '58~68분',
#    'review_count': 445,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 75,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210609180343749586_6d333ac5370e4c03f407cd63b2bbf3c1_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'address': '서울 서초구 방배동 925-3 1층',
#    'lat': 37.4852773427968,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['1인분주문', '프랜차이즈', '버거'],
#    'review_avg': 4.7,
#    'min_order_amount': 8000,
#    'distance': 0.32162211603999996,
#    'franchise_name': '(주)비케이알 / 버거킹',
#    'except_cash': False,
#    'name': '버거킹-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 203,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료~2,000원'},
#    'logo_url': '/media/franchise_logos/버거킹_20210609_Franchise_crop_200x200.jpg'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 7,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.1984765,
#    'app_order': True,
#    'lng': 126.996361190021,
#    'list_pos': 8,
#    'open': True,
#    'id': 545162,
#    'estimated_delivery_time': '23분',
#    'review_count': 130,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 1096,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20211108133157085193_b5ad6d48b4f7d9916440efad814ca98d_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:30:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4818781258087,
#    'end': '22:30:00',
#    'discount_until': None,
#    'categories': ['카페디저트', '샌드위치', '프랜차이즈'],
#    'review_avg': 4.5,
#    'min_order_amount': 8000,
#    'distance': 0.43133558483,
#    'franchise_name': '주식회사골든하인드 / 에그드랍',
#    'except_cash': True,
#    'name': '에그드랍-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '2,900원'},
#    'logo_url': '/media/franchise_logos/에그드랍OD_20211108_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 911-16 911-16 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 8,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.1850058,
#    'app_order': True,
#    'lng': 126.9962801,
#    'list_pos': 9,
#    'open': True,
#    'id': 309760,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 99,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 648,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201216172414729435_53a051bc3383ad3aa1d4add2ad938c6f_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4828112999307,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '카페디저트'],
#    'review_avg': 4.5,
#    'min_order_amount': 12000,
#    'distance': 0.39133190380000005,
#    'franchise_name': '투썸플레이스주식회사 / 투썸플레이스',
#    'except_cash': True,
#    'name': '투썸플레이스-방배역점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 83,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/투썸플레이스_20200323_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 910-14 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 9,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.1705075,
#    'app_order': True,
#    'lng': 126.983253206562,
#    'list_pos': 10,
#    'open': True,
#    'id': 458334,
#    'estimated_delivery_time': '42~52분',
#    'review_count': 0,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 1069,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 11000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 11000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200618110432510737_df539b0d143725c751cc0fe2863350c8_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'address': '서울 서초구 방배동 1461 인텔고시원 1층',
#    'lat': 37.4873012630914,
#    'end': '22:30:00',
#    'discount_until': None,
#    'categories': ['테이크아웃', '피자양식', '1인분주문', '프랜차이즈'],
#    'review_avg': 0.0,
#    'min_order_amount': 11000,
#    'distance': 0.87354275489,
#    'franchise_name': '(주)섹타나인양재지점 / PBDELI',
#    'except_cash': True,
#    'name': 'PB델리-방배현대점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/PBDELI_20200602_Franchise_crop_200x200.jpg'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 10,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.1554312,
#    'app_order': True,
#    'lng': 126.98384912789,
#    'list_pos': 11,
#    'open': True,
#    'id': 412563,
#    'estimated_delivery_time': '53~63분',
#    'review_count': 495,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 654,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 0},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609141652474942_28f5298ba9060adba417159b6e431f6b_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4859076399211,
#    'end': '00:30:00',
#    'discount_until': None,
#    'categories': ['찜탕', '테이크아웃', '야식', '프랜차이즈', '한식'],
#    'review_avg': 4.9,
#    'min_order_amount': 15000,
#    'distance': 0.7611439735200001,
#    'franchise_name': '(주)놀부 / 흥부찜닭',
#    'except_cash': False,
#    'name': '흥부찜닭by놀부-방배점',
#    'phone': '050718666886',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 493,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/흥부찜닭_20210722_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 11,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.1396792,
#    'app_order': True,
#    'lng': 126.9980937,
#    'list_pos': 12,
#    'open': True,
#    'id': 307910,
#    'estimated_delivery_time': '62~72분',
#    'review_count': 139,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 658,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 20000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 20000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210916141545830507_cfcb16e7cf3b6c29601e1067225e0dce_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4978795999326,
#    'end': '20:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '테이크아웃', '카페디저트'],
#    'review_avg': 4.7,
#    'min_order_amount': 15000,
#    'distance': 1.6853742360900001,
#    'franchise_name': '(주)섹타나인양재지점 / 파리크라상',
#    'except_cash': True,
#    'name': '파리크라상-반포서래점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 128,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/파리크라상_20190118_Franchise이미지약정서_crop_200x200.jpg',
#    'address': '서울 서초구 반포동 95-9 파리크라상 B1층, 1층~3층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 12,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.1375644,
#    'app_order': True,
#    'lng': 126.982210626987,
#    'list_pos': 13,
#    'open': True,
#    'id': 269413,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 426,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 360,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 13500}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190104155929495742_325275f4f488c134b10ea50dcda03005_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4803950280794,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['카페디저트', '테이크아웃', '프랜차이즈'],
#    'review_avg': 4.7,
#    'min_order_amount': 13500,
#    'distance': 0.92652163036,
#    'franchise_name': '(주)섹타나인양재지점 / 배스킨라빈스',
#    'except_cash': True,
#    'name': '배스킨라빈스-사당방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/배스킨라빈스_20201203_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 441-1 은혜빌딩 441-1 은혜빌딩 1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 13,
#    'adjusted_delivery_fee': 4400,
#    'is_available_delivery': True,
#    'new_rating': 0.1280678,
#    'app_order': True,
#    'lng': 127.019837040682,
#    'list_pos': 14,
#    'open': True,
#    'id': 477188,
#    'estimated_delivery_time': '32분',
#    'review_count': 306,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 561,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210105101758905543_759c74f1750da0e1c460897d7733a3c5_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.495193688217,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '피자양식'],
#    'review_avg': 4.8,
#    'min_order_amount': 20000,
#    'distance': 2.78217653971,
#    'franchise_name': '씨제이푸드빌(주) / 빕스',
#    'except_cash': True,
#    'name': '빕스얌딜리버리-서초점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 305,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '3,900원', 'basic': '4,400원'},
#    'logo_url': '/media/franchise_logos/빕스_20210105_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하1층 101호 내 22호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 14,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.1201688,
#    'app_order': True,
#    'lng': 126.983834026485,
#    'list_pos': 15,
#    'open': True,
#    'id': 412566,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 269,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 466,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 0},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142516509721_269e2943f6360fc91ebf89a61d6377b7_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4858976854135,
#    'end': '00:30:00',
#    'discount_until': None,
#    'categories': ['야식', '테이크아웃', '프랜차이즈', '분식'],
#    'review_avg': 4.7,
#    'min_order_amount': 17000,
#    'distance': 0.7620107606000001,
#    'franchise_name': '(주)놀부 / 돈까스퐁당떡볶이',
#    'except_cash': False,
#    'name': '돈까스퐁당떡볶이공수간-방배점',
#    'phone': '050718666858',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 269,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/돈까스퐁당떡볶이공수간_20180605_Franchise이미지약정서_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 866-10 방배 마에스트로 1동 지층 B103호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 30000,
#    'section_pos': 15,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.1200976,
#    'app_order': True,
#    'lng': 126.991831750109,
#    'list_pos': 16,
#    'open': True,
#    'id': 580805,
#    'estimated_delivery_time': '50~60분',
#    'review_count': 74,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 1088,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201027111706796895_e389fc3cde5601d8d4d3cfc0e05172a8_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '07:30:00',
#    'is_available_pickup': True,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4826184509201,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['한식', '프랜차이즈', '테이크아웃'],
#    'review_avg': 5.0,
#    'min_order_amount': 15000,
#    'distance': 0.10190949131,
#    'franchise_name': '족보잇는국밥 / 족보잇는국밥',
#    'except_cash': False,
#    'name': '족보잇는국밥&밀면-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료~2,000원'},
#    'logo_url': '/media/franchise_logos/족보잇는국밥_20201027_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 977-19 지호2빌딩 1층 104호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 16,
#    'adjusted_delivery_fee': 6400,
#    'is_available_delivery': True,
#    'new_rating': 0.1010464,
#    'app_order': True,
#    'lng': 127.022784829831,
#    'list_pos': 17,
#    'open': True,
#    'id': 447978,
#    'estimated_delivery_time': '29분',
#    'review_count': 609,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 606,
#    'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#     'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 5000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210305104101104679_1898275811e801451c972481bfbd8b45_tn.jpg',
#    'reachable': True,
#    'additional_discount': 5000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '09:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO', 'relayo'],
#    'representative_menus': '',
#    'lat': 37.5090438700747,
#    'end': '23:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '카페디저트'],
#    'review_avg': 4.9,
#    'min_order_amount': 14000,
#    'distance': 3.93107998696,
#    'franchise_name': '씨제이푸드빌(주) / 뚜레쥬르',
#    'except_cash': True,
#    'name': '뚜레쥬르-카페강남대로점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 65,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '5,900원', 'basic': '6,400원'},
#    'logo_url': '/media/franchise_logos/뚜레쥬르_20201224_Franchise_crop_200x200.jpg',
#    'address': '서울 강남구 논현동 143-15 건일빌딩 지상1층 102, 103, 104호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 17,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.0749984,
#    'app_order': True,
#    'lng': 126.993691269825,
#    'list_pos': 18,
#    'open': True,
#    'id': 347986,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 1,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'grocery',
#    'franchise_id': 682,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 20000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190724190643197177_bf9703916c8d6d472b0f5460c3285315_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4836753900094,
#    'end': '00:20:00',
#    'discount_until': None,
#    'categories': ['카페디저트', '편의점', '프랜차이즈'],
#    'review_avg': 5.0,
#    'min_order_amount': 10000,
#    'distance': 0.15546198832,
#    'franchise_name': '(주)비지에프리테일 / CU',
#    'except_cash': True,
#    'name': 'CU-방배원점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/CU_20190322_Franchise이미지약정서_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 928-30 1층 102호'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 18,
#    'adjusted_delivery_fee': 3500,
#    'is_available_delivery': True,
#    'new_rating': 0.0733577,
#    'app_order': True,
#    'lng': 126.981016514431,
#    'list_pos': 19,
#    'open': True,
#    'id': 480587,
#    'estimated_delivery_time': '48~58분',
#    'review_count': 109,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 11,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 0}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210708151455503770_7af4f397aee2f1cd161287c8a2e9503a_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4874564443125,
#    'end': '21:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '테이크아웃', '치킨', '버거'],
#    'review_avg': 4.7,
#    'min_order_amount': 12000,
#    'distance': 1.05795957855,
#    'franchise_name': '주식회사맘스터치앤컴퍼니 / 맘스터치',
#    'except_cash': False,
#    'name': '맘스터치-이수점',
#    'phone': '050352914628',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 81,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,500원'},
#    'logo_url': '/media/franchise_logos/맘스터치_20201116_Franchise_crop_200x200.jpg',
#    'address': '서울 동작구 사당동 139-21 서범빌딩 2층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 19,
#    'adjusted_delivery_fee': 4000,
#    'is_available_delivery': True,
#    'new_rating': 0.0723532,
#    'app_order': True,
#    'lng': 127.017751585306,
#    'list_pos': 20,
#    'open': True,
#    'id': 528245,
#    'estimated_delivery_time': '59~69분',
#    'review_count': 114,
#    'discount_from': '2021-11-12T10:00:00',
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 1200,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 14000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 14000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210113183058604180_b0d241df252d57d98e2349164f936480_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.5153529257566,
#    'end': '23:00:00',
#    'discount_until': '2021-11-12T22:59:59.999999',
#    'categories': ['테이크아웃', '한식', '프랜차이즈', '분식'],
#    'review_avg': 4.3,
#    'min_order_amount': 12000,
#    'distance': 4.20784353862,
#    'franchise_name': '주식회사기영에프앤비 / 떡볶이참잘하는집',
#    'except_cash': False,
#    'name': '떡참떡볶이참잘하는집-신사점',
#    'phone': '050352965341',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 5,
#    'delivery_fee_to_display': {'basic': '4,000원'},
#    'logo_url': '/media/franchise_logos/떡볶이참잘하는집_20210511_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 잠원동 19-5 영서빌딩 19-5 영서빌딩 1층 102-1호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 20,
#    'adjusted_delivery_fee': 4000,
#    'is_available_delivery': True,
#    'new_rating': 0.0722909,
#    'app_order': True,
#    'lng': 126.980670800628,
#    'list_pos': 21,
#    'open': True,
#    'id': 276150,
#    'estimated_delivery_time': '65~75분',
#    'review_count': 171,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 482,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 12000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 4000,
#       'discount_mov': 10000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201125155657338485_55cbe86cc9acdc021dcc4eebf1ef4fdd_tn.jpg',
#    'reachable': True,
#    'additional_discount': 4000,
#    'new': False,
#    'minimum_pickup_minutes': 30,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4877135667658,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['카페디저트', '테이크아웃', '프랜차이즈', '샌드위치'],
#    'review_avg': 4.6,
#    'min_order_amount': 12000,
#    'distance': 1.0976230035399999,
#    'franchise_name': '(주)섹타나인양재지점 / 파스쿠찌',
#    'except_cash': True,
#    'name': '파스쿠찌-이수역점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 170,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '4,000원'},
#    'logo_url': '/media/franchise_logos/파스쿠치_20180419_Franchise이미지약정서_crop_200x200.png',
#    'address': '서울 동작구 사당동 139-36 1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 50000,
#    'section_pos': 21,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.0721318,
#    'app_order': True,
#    'lng': 126.9811218,
#    'list_pos': 22,
#    'open': True,
#    'id': 245184,
#    'estimated_delivery_time': '24~34분',
#    'review_count': 249,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 57,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 0},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': True,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142016465916_6b436eb8d8f13966dc17ccaba8707746_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4756087,
#    'end': '21:00:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '테이크아웃', '한식'],
#    'review_avg': 4.6,
#    'min_order_amount': 19000,
#    'distance': 1.2988844799900001,
#    'franchise_name': '(주)놀부 / 놀부부대찌개',
#    'except_cash': True,
#    'name': '놀부부대찌개-사당점',
#    'phone': '050712905313',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 44,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료~3,000원'},
#    'logo_url': '/media/franchise_logos/놀부부대찌개_20200224_Franchise_crop_200x200.jpg',
#    'address': '서울 관악구 남현동 1061-3'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 22,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.060701,
#    'app_order': True,
#    'lng': 126.986717854856,
#    'list_pos': 23,
#    'open': True,
#    'id': 489659,
#    'estimated_delivery_time': '45~55분',
#    'review_count': 0,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'grocery',
#    'franchise_id': 970,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 5000,
#       'discount_mov': 20000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200318155630676175_026d8e9a3cfb1f08765589cbc5eb77fe_tn.jpg',
#    'reachable': True,
#    'additional_discount': 5000,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.483427116581,
#    'end': '00:30:00',
#    'discount_until': None,
#    'categories': ['편의점', '카페디저트', '프랜차이즈'],
#    'review_avg': 0.0,
#    'min_order_amount': 10000,
#    'distance': 0.46082361567999996,
#    'franchise_name': '(주)코리아세븐 / 세븐일레븐',
#    'except_cash': True,
#    'name': '세븐일레븐-방배17호점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/세븐일레븐_20200214_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 방배동 957-3 쌍영빌딩'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 23,
#    'adjusted_delivery_fee': 4500,
#    'is_available_delivery': True,
#    'new_rating': 0.059567,
#    'app_order': True,
#    'lng': 126.978935482903,
#    'list_pos': 24,
#    'open': True,
#    'id': 338975,
#    'estimated_delivery_time': '43~53분',
#    'review_count': 204,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 737,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 8000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 8000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210304145050593054_cadbe91eb266a0edcc9fbbfff3bd4cc2_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '09:00:00',
#    'is_available_pickup': True,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4780858644222,
#    'end': '23:00:00',
#    'discount_until': None,
#    'categories': ['한식', '프랜차이즈', '테이크아웃', '1인분주문', '찜탕'],
#    'review_avg': 4.6,
#    'min_order_amount': 9000,
#    'distance': 1.2973604187,
#    'franchise_name': '주식회사보강엔터프라이즈 / 큰맘할매순대국',
#    'except_cash': False,
#    'name': '큰맘할매순대국-사당점',
#    'phone': '050712994967',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 43,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '4,500원'},
#    'logo_url': '/media/franchise_logos/큰맘할매순대국_20210225_Franchise_crop_200x200.jpg',
#    'address': '서울 동작구 사당동 1038-33 1층'},
#   {'phone_order': True,
#    'free_delivery_threshold': 0,
#    'section_pos': 24,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.0566534,
#    'app_order': True,
#    'lng': 127.028227186052,
#    'list_pos': 25,
#    'open': True,
#    'id': 480267,
#    'estimated_delivery_time': '50~60분',
#    'review_count': 40,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'hotdeal',
#    'restaurant_type': 'food',
#    'franchise_id': 946,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 2000,
#       'discount_mov': 15000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210426163253885793_c6062f66634c78b5a400f57d86b12cd8_tn.jpg',
#    'reachable': True,
#    'additional_discount': 2000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:45:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4991963367523,
#    'end': '15:00:00',
#    'discount_until': None,
#    'categories': ['피자양식', '프랜차이즈', '테이크아웃'],
#    'review_avg': 4.5,
#    'min_order_amount': 14900,
#    'distance': 3.64480799246,
#    'franchise_name': '주식회사고피자 / 고피자',
#    'except_cash': False,
#    'name': '고피자-강남점',
#    'phone': '050352914315',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 38,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/고피자_20210426_Franchise_crop_200x200_FfCNdy9.jpg',
#    'address': '서울 강남구 역삼동 819 지하1층 4호'},
#   {'phone_order': True,
#    'section_pos': 1,
#    'adjusted_delivery_fee': 0,
#    'is_available_delivery': True,
#    'new_rating': 0.5646999,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.986111666233,
#    'list_pos': 26,
#    'open': True,
#    'id': 331884,
#    'estimated_delivery_time': '29~39분',
#    'review_count': 1896,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210419110000000000_e0eb1a89146b627034d7c9489b5d7d7a_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '09:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4952843427448,
#    'end': '20:50:00',
#    'discount_until': None,
#    'categories': ['중식'],
#    'review_avg': 4.5,
#    'min_order_amount': 10000,
#    'distance': 1.4044038211899998,
#    'minimum_pickup_minutes': 0,
#    'except_cash': False,
#    'name': '동원-방배점',
#    'phone': '050712988101',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1647,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료'},
#    'logo_url': '/media/restaurant_logos/스탁_20210623_DHK내부_짜장면_Side01_300x300_RVDI84_VKaprBf.jpg',
#    'address': '서울 서초구 방배동 769-1 2층'},
#   {'phone_order': False,
#    'section_pos': 2,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.5187458,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.983402953314,
#    'list_pos': 27,
#    'open': True,
#    'id': 574509,
#    'estimated_delivery_time': '21분',
#    'review_count': 177,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 2900, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210720103514843292_3f0009cc923fdb0476bc4eeddcd0f492_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4874676953048,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['고기구이', '프랜차이즈', '1인분주문', '한식'],
#    'review_avg': 4.6,
#    'min_order_amount': 8900,
#    'distance': 0.8711246434800001,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '덮다-방배점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 177,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '무료', 'basic': '2,900원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20210720_574509_덮다-방배점_대표사진_300x300.jpg',
#    'address': '서울 서초구 방배동 1458 2층'},
#   {'phone_order': True,
#    'section_pos': 3,
#    'adjusted_delivery_fee': 0,
#    'is_available_delivery': True,
#    'new_rating': 0.5142113,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 127.015078736975,
#    'list_pos': 28,
#    'open': True,
#    'id': 458367,
#    'estimated_delivery_time': '41~51분',
#    'review_count': 1422,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210419110000000000_32912f1c0a8a1ff06a4cf1d9091f3c0a_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:30:00',
#    'is_available_pickup': True,
#    'tags': ['excellent'],
#    'representative_menus': '',
#    'lat': 37.4883093685504,
#    'end': '21:00:00',
#    'discount_until': None,
#    'categories': ['중식', '1인분주문', '아시안', '테이크아웃'],
#    'review_avg': 4.9,
#    'min_order_amount': 6000,
#    'distance': 2.10972309399,
#    'minimum_pickup_minutes': 20,
#    'except_cash': False,
#    'name': '취홍-서울교대점',
#    'phone': '050352881878',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 4,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료'},
#    'logo_url': '/media/restaurant_logos/스탁_20190917_DHK촬영합성_간짜장-차돌박이짬뽕-탕수육_Top01_300x300_OZBTUwf.jpg',
#    'address': '서울 서초구 서초동 1624-2 서초제일빌딩 지하1층'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 4,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': -0.3642283,
#    'app_order': True,
#    'lng': 126.982851850389,
#    'list_pos': 29,
#    'open': True,
#    'id': 1031154,
#    'estimated_delivery_time': '20분',
#    'review_count': 0,
# ...
#    'address': '서울 서초구 방배동 444-3 SK리더스뷰 101호 일부'},
#   {'phone_order': False,
#    'section_pos': 26,
#    'adjusted_delivery_fee': 3400,
#    'is_available_delivery': True,
#    'new_rating': 0.3874802,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.973214881183,
#    'list_pos': 51,
#    'open': True,
#    'id': 532071,
#    'estimated_delivery_time': '24분',
#    'review_count': 56,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 1000, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210115181657466161_efadff88b2fcda2bd01c3f98b1cad0dc_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4762561328101,
#    'end': '12:00:00',
#    'discount_until': None,
#    'categories': ['카페디저트'],
#    'review_avg': 5.0,
#    'min_order_amount': 8400,
#    'distance': 1.83961276254,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '라자루스카페',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 4,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '1,900원', 'basic': '3,400원'},
#    'logo_url': '/media/restaurant_logos/스탁_20190801_DHK촬영_아메리카노HOT_Side01_300x300_DMQEuH7.jpg',
#    'address': '서울 동작구 사당동 1049-7 중앙대학교동창회관 1층 2호'},
#   {'phone_order': True,
#    'section_pos': 27,
#    'adjusted_delivery_fee': 3000,
#    'is_available_delivery': True,
#    'new_rating': 0.3849381,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.983083724903,
#    'list_pos': 52,
#    'open': True,
#    'id': 410782,
#    'estimated_delivery_time': '52~62분',
#    'review_count': 1684,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 37,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20191014171511754363_c7be81a92573dbcea9bc5988012d0051_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': '(주)비에이치씨 / BHC치킨',
#    'thumbnail_message': '',
#    'begin': '09:00:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO', 'relayo'],
#    'representative_menus': '',
#    'lat': 37.4860317859567,
#    'end': '23:50:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '테이크아웃', '치킨'],
#    'review_avg': 4.8,
#    'min_order_amount': 15000,
#    'distance': 0.82933680184,
#    'minimum_pickup_minutes': 20,
#    'except_cash': False,
#    'name': 'BHC-이수점',
#    'phone': '050718667052',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1183,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '3,000원'},
#    'logo_url': '/media/franchise_logos/BHC_20210329_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 3001-2 방배디오슈페리움1 3001-2 방배디오슈페리움1 104, 104-1호'},
#   {'phone_order': True,
#    'section_pos': 28,
#    'adjusted_delivery_fee': 2800,
#    'is_available_delivery': True,
#    'new_rating': 0.3806494,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 127.013923901648,
#    'list_pos': 53,
#    'open': True,
#    'id': 354615,
#    'estimated_delivery_time': '60~70분',
#    'review_count': 1537,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 1366,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210614104231543480_14b8dfa7b30e20334dcb46b062104dee_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': '(주)씨디씨 / 마라하오',
#    'thumbnail_message': '',
#    'begin': '10:30:00',
#    'is_available_pickup': True,
#    'tags': ['CESCO'],
#    'representative_menus': '',
#    'lat': 37.4965683030573,
#    'end': '02:00:00',
#    'discount_until': None,
#    'categories': ['아시안', '프랜차이즈', '중식', '테이크아웃', '야식', '찜탕'],
#    'review_avg': 4.7,
#    'min_order_amount': 12900,
#    'distance': 2.4215875426399998,
#    'minimum_pickup_minutes': 20,
#    'except_cash': False,
#    'name': '마라하오-서초점',
#    'phone': '050718609871',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 1185,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,800원'},
#    'logo_url': '/media/franchise_logos/마라하오_20210614_Franchise_crop_200x200.jpg',
#    'address': '서울 서초구 서초동 1698-3 청석빌딩 지하1층'},
#   {'phone_order': True,
#    'section_pos': 29,
#    'adjusted_delivery_fee': 1000,
#    'is_available_delivery': True,
#    'new_rating': 0.3783313,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.982612958792,
#    'list_pos': 54,
#    'open': True,
#    'id': 286881,
#    'estimated_delivery_time': '40~50분',
#    'review_count': 1106,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 712,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20211108122607571169_9bd3bf281ba610597e7b22ce01db2fd9_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'minimum_pickup_minutes': 0,
#    'thumbnail_message': '',
#    'begin': '10:40:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'address': '서울 서초구 방배동 3001-1 디오슈페리움2 102호',
#    'lat': 37.4860432880112,
#    'end': '21:30:00',
#    'discount_until': None,
#    'categories': ['프랜차이즈', '분식', '아시안', '한식'],
#    'review_avg': 4.7,
#    'min_order_amount': 12000,
#    'distance': 0.86899219502,
#    'franchise_name': '(주)엠푸드에스엔시 / 미스사이공',
#    'except_cash': False,
#    'name': '베트남쌀국수미스사이공-이수점',
#    'phone': '050712945444',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 123,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '1,000원'},
#    'logo_url': '/media/franchise_logos/미스사이공_20190517_Franchise_crop_200x200.jpg'},
#   {'phone_order': False,
#    'section_pos': 30,
#    'adjusted_delivery_fee': 2900,
#    'is_available_delivery': True,
#    'new_rating': 0.3759198,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.988846353989,
#    'list_pos': 55,
#    'open': True,
#    'id': 571296,
#    'estimated_delivery_time': '21분',
#    'review_count': 0,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 500, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210614130000000000_0a49177ac7d48b117288b184f024ea37_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '09:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.495779703385,
#    'end': '21:00:00',
#    'discount_until': None,
#    'categories': ['카페디저트'],
#    'review_avg': 0.0,
#    'min_order_amount': 12000,
#    'distance': 1.38905613158,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '해피커피',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '1,900원', 'basic': '2,900원'},
#    'logo_url': '/media/restaurant_logos/스탁_20190801_DHK촬영_그린티라떼HOT-아메리카노ICE-에스프레소_Top02_300x300_9dFS5d3.jpg',
#    'address': '서울 서초구 방배동 19-3 1층 107호'},
#   {'phone_order': False,
#    'free_delivery_threshold': 0,
#    'section_pos': 31,
#    'adjusted_delivery_fee': 3900,
#    'is_available_delivery': True,
#    'new_rating': -0.4000612,
#    'app_order': True,
#    'lng': 127.013418784531,
#    'list_pos': 56,
#    'open': True,
#    'id': 1028988,
#    'estimated_delivery_time': '23분',
#    'review_count': 2,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 1000, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20211110101832765389_8ee61acb7247dd2bb374589921bc1e67_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': True,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4930094310671,
#    'end': '21:00:00',
#    'discount_until': None,
#    'categories': ['한식', '도시락죽', '찜탕'],
#    'review_avg': 5.0,
#    'min_order_amount': 15000,
#    'distance': 2.1685456834699997,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '립이야등갈비',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 2,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '3,900원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20211110_1028988_립이야등갈비_대표사진_300x300.jpg',
#    'address': '서울특별시 서초구 서초동 1573-10 로이어즈타워 지하1층 B18호'},
#   {'phone_order': True,
#    'section_pos': 32,
#    'adjusted_delivery_fee': 4000,
#    'is_available_delivery': True,
#    'new_rating': 0.3685157,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 127.026121185242,
#    'list_pos': 57,
#    'open': True,
#    'id': 413273,
#    'estimated_delivery_time': '46~56분',
#    'review_count': 13505,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210716174409966897_fef4e82b00807e2c7b85790e038c3d2e_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': False,
#    'tags': ['CESCO', 'excellent'],
#    'representative_menus': '',
#    'lat': 37.5072362315182,
#    'end': '09:59:00',
#    'discount_until': None,
#    'categories': ['족발보쌈'],
#    'review_avg': 4.8,
#    'min_order_amount': 11000,
#    'distance': 4.00526619076,
#    'minimum_pickup_minutes': 0,
#    'except_cash': False,
#    'name': '기대만족-본점',
#    'phone': '050718667411',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 13485,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '4,000원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20200116_413273_기대만족-강남본점_대표사진_300x300_JyNNjjj.jpg',
#    'address': '서울 강남구 논현동 181-14 지하1층'},
#   {'phone_order': True,
#    'section_pos': 33,
#    'adjusted_delivery_fee': 1900,
#    'is_available_delivery': True,
#    'new_rating': 0.3638203,
#    'app_order': True,
#    'free_delivery_threshold': 45000,
#    'lng': 126.994658186875,
#    'list_pos': 58,
#    'open': True,
#    'id': 502995,
#    'estimated_delivery_time': '37~47분',
#    'review_count': 896,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 379,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 6000,
#       'discount_mov': 18800},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 6000,
#       'discount_mov': 18800}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210907135553365328_005b0b30e6d7cf00336014679aea181c_tn.jpg',
#    'reachable': True,
#    'additional_discount': 6000,
#    'new': False,
#    'minimum_pickup_minutes': 20,
#    'thumbnail_message': '',
#    'begin': '10:00:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4826159849125,
#    'end': '02:00:00',
#    'discount_until': None,
#    'categories': ['한식', '찜탕', '테이크아웃', '프랜차이즈'],
#    'review_avg': 4.9,
#    'min_order_amount': 16000,
#    'distance': 0.26062970442,
#    'franchise_name': '주식회사기영에프앤비 / 두찜',
#    'except_cash': False,
#    'name': '두마리찜닭두찜-서초방배점',
#    'phone': '050352938520',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 786,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '무료~1,900원'},
#    'logo_url': '/media/franchise_logos/두찜_20191219_Franchise_crop_200x200.jpg',
#    'address': '서울특별시 서초구 방배동 922-24 922-24 1층'},
#   {'phone_order': False,
#    'section_pos': 34,
#    'adjusted_delivery_fee': 2000,
#    'is_available_delivery': True,
#    'new_rating': 0.3591383,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 126.9813316,
#    'list_pos': 59,
#    'open': True,
#    'id': 289550,
#    'estimated_delivery_time': '55~65분',
#    'review_count': 1064,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': 475,
#    'discounts': {'additional': {'delivery': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 12000},
#      'pickup': {'only_for_member': True,
#       'is_per_menu': False,
#       'amount': 3000,
#       'discount_mov': 12000}}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20191224184656261511_b805645605e9421d51b14065d899f0e4_tn.jpg',
#    'reachable': True,
#    'additional_discount': 3000,
#    'new': False,
#    'minimum_pickup_minutes': 10,
#    'thumbnail_message': '',
#    'begin': '10:20:00',
#    'is_available_pickup': True,
#    'tags': ['relayo'],
#    'representative_menus': '',
#    'lat': 37.4787069999301,
#    'end': '22:00:00',
#    'discount_until': None,
#    'categories': ['테이크아웃', '카페디저트', '프랜차이즈'],
#    'review_avg': 4.9,
#    'min_order_amount': 12000,
#    'distance': 1.07878402744,
#    'franchise_name': '(주)섹타나인양재지점 / 파리바게뜨',
#    'except_cash': True,
#    'name': '파리바게뜨-사당역점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['online'],
#    'delivery_method': 'VD',
#    'owner_reply_count': 385,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'basic': '2,000원'},
#    'logo_url': '/media/franchise_logos/파리바게뜨_20180712_Franchise이미지약정서_crop_200x200_s6Zm07l.jpg',
#    'address': '서울 동작구 사당동 1031-28'},
#   {'phone_order': False,
#    'section_pos': 35,
#    'adjusted_delivery_fee': 3400,
#    'is_available_delivery': True,
#    'new_rating': 0.3489582,
#    'app_order': True,
#    'free_delivery_threshold': 0,
#    'lng': 127.009615169499,
#    'list_pos': 60,
#    'open': True,
#    'id': 332627,
#    'estimated_delivery_time': '20분',
#    'review_count': 126,
#    'discount_from': None,
#    'is_deliverable': True,
#    'section': 'contract',
#    'restaurant_type': 'food',
#    'franchise_id': None,
#    'discounts': {'delivery_fee': {'funding': 3400, 'campaign': 500}},
#    'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20211018130000000000_670327a7db4d8ff832d927528ce14e84_tn.jpg',
#    'reachable': True,
#    'additional_discount': 0,
#    'new': False,
#    'franchise_name': None,
#    'thumbnail_message': '',
#    'begin': '10:15:00',
#    'is_available_pickup': False,
#    'tags': [],
#    'representative_menus': '',
#    'lat': 37.4893743651715,
#    'end': '22:35:00',
#    'discount_until': None,
#    'categories': ['피자양식'],
#    'review_avg': 4.8,
#    'min_order_amount': 14000,
#    'distance': 1.68957117763,
#    'minimum_pickup_minutes': 0,
#    'except_cash': True,
#    'name': '펠리스산쵸-서초점',
#    'phone': '0000000000',
#    'reason': None,
#    'payment_methods': ['creditcard', 'online'],
#    'delivery_method': 'OD',
#    'owner_reply_count': 0,
#    'discount_percent': 0,
#    'delivery_fee_to_display': {'discounted': '무료', 'basic': '3,400원'},
#    'logo_url': '/media/restaurant_logos/업체자체_20210329_332627_펠리스산쵸-서초점_대표사진_300x300.jpg',
#    'address': '서울 서초구 서초동 1544-9 세바빌딩 1층 1호'}]}

# %%
ygy_data['restaurants'] # 식당정보가 담긴 dict
# Out:
# [{'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 1,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.2521561,
#   'app_order': True,
#   'lng': 126.9860396,
#   'list_pos': 1,
#   'open': True,
#   'id': 54915,
#   'estimated_delivery_time': '25~35분',
#   'review_count': 1375,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'superlist',
#   'restaurant_type': 'food',
#   'franchise_id': 82,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20181004182813010545_d61c21551fb145915b554bc893ffe4f5_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': '주식회사김가네 / 김가네',
#   'thumbnail_message': '',
#   'begin': '09:30:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.49387,
#   'end': '20:20:00',
#   'discount_until': None,
#   'categories': ['분식', '한식', '프랜차이즈'],
#   'review_avg': 4.6,
#   'min_order_amount': 15000,
#   'distance': 1.26198076014,
#   'minimum_pickup_minutes': 0,
#   'except_cash': False,
#   'name': '김가네-방배본동점',
#   'phone': '050352561515',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 51,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/김가네_20210114_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 778-8'},
#  {'phone_order': True,
#   'free_delivery_threshold': 45000,
#   'section_pos': 1,
#   'adjusted_delivery_fee': 1900,
#   'is_available_delivery': True,
#   'new_rating': 0.3638203,
#   'app_order': True,
#   'lng': 126.994658186875,
#   'list_pos': 2,
#   'open': True,
#   'id': 502995,
#   'estimated_delivery_time': '37~47분',
#   'review_count': 896,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 379,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 6000,
#      'discount_mov': 18800},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 6000,
#      'discount_mov': 18800}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210907135553365328_005b0b30e6d7cf00336014679aea181c_tn.jpg',
#   'reachable': True,
#   'additional_discount': 6000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4826159849125,
#   'end': '02:00:00',
#   'discount_until': None,
#   'categories': ['한식', '찜탕', '테이크아웃', '프랜차이즈'],
#   'review_avg': 4.9,
#   'min_order_amount': 16000,
#   'distance': 0.26062970442,
#   'franchise_name': '주식회사기영에프앤비 / 두찜',
#   'except_cash': False,
#   'name': '두마리찜닭두찜-서초방배점',
#   'phone': '050352938520',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 786,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료~1,900원'},
#   'logo_url': '/media/franchise_logos/두찜_20191219_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 922-24 922-24 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 2,
#   'adjusted_delivery_fee': 3400,
#   'is_available_delivery': True,
#   'new_rating': 0.309344,
#   'app_order': True,
#   'lng': 127.008321356362,
#   'list_pos': 3,
#   'open': True,
#   'id': 348355,
#   'estimated_delivery_time': '20분',
#   'review_count': 711,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 24,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201223142237116456_27c175f00c0a134b968bbd9b9d14f353_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4915466145201,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '족발보쌈'],
#   'review_avg': 4.6,
#   'min_order_amount': 12000,
#   'distance': 1.69816528699,
#   'franchise_name': '(주)놀부 / 놀부보쌈',
#   'except_cash': True,
#   'name': '놀부보쌈족발-서초점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 693,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '2,900원', 'basic': '3,400원'},
#   'logo_url': '/media/franchise_logos/놀부보쌈_20201223_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1542-1 지하1층 비18,19호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 3,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.304946,
#   'app_order': True,
#   'lng': 127.01983358,
#   'list_pos': 4,
#   'open': True,
#   'id': 487219,
#   'estimated_delivery_time': '52~62분',
#   'review_count': 1172,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 34,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 3000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210928141110387017_e8b104f2e9e7af49295a78df14ee7d1d_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '10:30:00',
#   'is_available_pickup': True,
#   'tags': ['excellent'],
#   'representative_menus': '',
#   'lat': 37.4952002356867,
#   'end': '02:30:00',
#   'discount_until': None,
#   'categories': ['치킨', '프랜차이즈', '야식', '테이크아웃'],
#   'review_avg': 4.8,
#   'min_order_amount': 16000,
#   'distance': 2.78224577834,
#   'franchise_name': '(주)컬투에프앤비 / 컬투치킨',
#   'except_cash': False,
#   'name': '컬투치킨-서초1호점',
#   'phone': '050352921309',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1020,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/컬투치킨_20180309_Franchise이미지약정서_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하 1층 9호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 4,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.2868763,
#   'app_order': True,
#   'lng': 126.98384912789,
#   'list_pos': 5,
#   'open': True,
#   'id': 412564,
#   'estimated_delivery_time': '44~54분',
#   'review_count': 969,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 548,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 0},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142552546157_f0b60b578881144774d34ceb4d0785eb_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4859076399211,
#   'end': '00:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '고기구이', '야식', '한식', '테이크아웃'],
#   'review_avg': 4.8,
#   'min_order_amount': 17000,
#   'distance': 0.7611439735200001,
#   'franchise_name': '(주)놀부 / 쫄면주는삼겹본능',
#   'except_cash': False,
#   'name': '쫄면주는삼겹본능by놀부-방배점',
#   'phone': '050718667053',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 959,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/쫄면주는삼겹본능_20210722_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 5,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.2485344,
#   'app_order': True,
#   'lng': 126.999144987723,
#   'list_pos': 6,
#   'open': True,
#   'id': 282337,
#   'estimated_delivery_time': '58~68분',
#   'review_count': 386,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 475,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 12000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 12000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20191224184656261511_b805645605e9421d51b14065d899f0e4_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4797357992263,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '카페디저트', '테이크아웃'],
#   'review_avg': 4.7,
#   'min_order_amount': 12000,
#   'distance': 0.76315974389,
#   'franchise_name': '(주)섹타나인양재지점 / 파리바게뜨',
#   'except_cash': True,
#   'name': '파리바게뜨-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 67,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/파리바게뜨_20180712_Franchise이미지약정서_crop_200x200_s6Zm07l.jpg',
#   'address': '서울 서초구 방배동 1022-1 우진빌딩 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 13000,
#   'section_pos': 6,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.2311734,
#   'app_order': True,
#   'lng': 126.994844496436,
#   'list_pos': 7,
#   'open': True,
#   'id': 327229,
#   'estimated_delivery_time': '58~68분',
#   'review_count': 445,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 75,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210609180343749586_6d333ac5370e4c03f407cd63b2bbf3c1_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'address': '서울 서초구 방배동 925-3 1층',
#   'lat': 37.4852773427968,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['1인분주문', '프랜차이즈', '버거'],
#   'review_avg': 4.7,
#   'min_order_amount': 8000,
#   'distance': 0.32162211603999996,
#   'franchise_name': '(주)비케이알 / 버거킹',
#   'except_cash': False,
#   'name': '버거킹-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 203,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료~2,000원'},
#   'logo_url': '/media/franchise_logos/버거킹_20210609_Franchise_crop_200x200.jpg'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 7,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.1984765,
#   'app_order': True,
#   'lng': 126.996361190021,
#   'list_pos': 8,
#   'open': True,
#   'id': 545162,
#   'estimated_delivery_time': '23분',
#   'review_count': 130,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 1096,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20211108133157085193_b5ad6d48b4f7d9916440efad814ca98d_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:30:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4818781258087,
#   'end': '22:30:00',
#   'discount_until': None,
#   'categories': ['카페디저트', '샌드위치', '프랜차이즈'],
#   'review_avg': 4.5,
#   'min_order_amount': 8000,
#   'distance': 0.43133558483,
#   'franchise_name': '주식회사골든하인드 / 에그드랍',
#   'except_cash': True,
#   'name': '에그드랍-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '2,900원'},
#   'logo_url': '/media/franchise_logos/에그드랍OD_20211108_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 911-16 911-16 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 8,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.1850058,
#   'app_order': True,
#   'lng': 126.9962801,
#   'list_pos': 9,
#   'open': True,
#   'id': 309760,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 99,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 648,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201216172414729435_53a051bc3383ad3aa1d4add2ad938c6f_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4828112999307,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '카페디저트'],
#   'review_avg': 4.5,
#   'min_order_amount': 12000,
#   'distance': 0.39133190380000005,
#   'franchise_name': '투썸플레이스주식회사 / 투썸플레이스',
#   'except_cash': True,
#   'name': '투썸플레이스-방배역점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 83,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/투썸플레이스_20200323_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 910-14 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 9,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.1705075,
#   'app_order': True,
#   'lng': 126.983253206562,
#   'list_pos': 10,
#   'open': True,
#   'id': 458334,
#   'estimated_delivery_time': '42~52분',
#   'review_count': 0,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 1069,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 11000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 11000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200618110432510737_df539b0d143725c751cc0fe2863350c8_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'address': '서울 서초구 방배동 1461 인텔고시원 1층',
#   'lat': 37.4873012630914,
#   'end': '22:30:00',
#   'discount_until': None,
#   'categories': ['테이크아웃', '피자양식', '1인분주문', '프랜차이즈'],
#   'review_avg': 0.0,
#   'min_order_amount': 11000,
#   'distance': 0.87354275489,
#   'franchise_name': '(주)섹타나인양재지점 / PBDELI',
#   'except_cash': True,
#   'name': 'PB델리-방배현대점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/PBDELI_20200602_Franchise_crop_200x200.jpg'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 10,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.1554312,
#   'app_order': True,
#   'lng': 126.98384912789,
#   'list_pos': 11,
#   'open': True,
#   'id': 412563,
#   'estimated_delivery_time': '53~63분',
#   'review_count': 495,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 654,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 0},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609141652474942_28f5298ba9060adba417159b6e431f6b_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4859076399211,
#   'end': '00:30:00',
#   'discount_until': None,
#   'categories': ['찜탕', '테이크아웃', '야식', '프랜차이즈', '한식'],
#   'review_avg': 4.9,
#   'min_order_amount': 15000,
#   'distance': 0.7611439735200001,
#   'franchise_name': '(주)놀부 / 흥부찜닭',
#   'except_cash': False,
#   'name': '흥부찜닭by놀부-방배점',
#   'phone': '050718666886',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 493,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/흥부찜닭_20210722_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 866-10 방배 마에스트로 866-10 방배 마에스트로 1동 지층 B103호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 11,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.1396792,
#   'app_order': True,
#   'lng': 126.9980937,
#   'list_pos': 12,
#   'open': True,
#   'id': 307910,
#   'estimated_delivery_time': '62~72분',
#   'review_count': 139,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 658,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 20000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 20000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210916141545830507_cfcb16e7cf3b6c29601e1067225e0dce_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4978795999326,
#   'end': '20:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '테이크아웃', '카페디저트'],
#   'review_avg': 4.7,
#   'min_order_amount': 15000,
#   'distance': 1.6853742360900001,
#   'franchise_name': '(주)섹타나인양재지점 / 파리크라상',
#   'except_cash': True,
#   'name': '파리크라상-반포서래점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 128,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/파리크라상_20190118_Franchise이미지약정서_crop_200x200.jpg',
#   'address': '서울 서초구 반포동 95-9 파리크라상 B1층, 1층~3층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 12,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.1375644,
#   'app_order': True,
#   'lng': 126.982210626987,
#   'list_pos': 13,
#   'open': True,
#   'id': 269413,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 426,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 360,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 13500}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190104155929495742_325275f4f488c134b10ea50dcda03005_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4803950280794,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['카페디저트', '테이크아웃', '프랜차이즈'],
#   'review_avg': 4.7,
#   'min_order_amount': 13500,
#   'distance': 0.92652163036,
#   'franchise_name': '(주)섹타나인양재지점 / 배스킨라빈스',
#   'except_cash': True,
#   'name': '배스킨라빈스-사당방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/배스킨라빈스_20201203_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 441-1 은혜빌딩 441-1 은혜빌딩 1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 13,
#   'adjusted_delivery_fee': 4400,
#   'is_available_delivery': True,
#   'new_rating': 0.1280678,
#   'app_order': True,
#   'lng': 127.019837040682,
#   'list_pos': 14,
#   'open': True,
#   'id': 477188,
#   'estimated_delivery_time': '32분',
#   'review_count': 306,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 561,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210105101758905543_759c74f1750da0e1c460897d7733a3c5_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.495193688217,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '피자양식'],
#   'review_avg': 4.8,
#   'min_order_amount': 20000,
#   'distance': 2.78217653971,
#   'franchise_name': '씨제이푸드빌(주) / 빕스',
#   'except_cash': True,
#   'name': '빕스얌딜리버리-서초점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 305,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '3,900원', 'basic': '4,400원'},
#   'logo_url': '/media/franchise_logos/빕스_20210105_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1678-2 서초동동아빌라트 지하1층 101호 내 22호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 14,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.1201688,
#   'app_order': True,
#   'lng': 126.983834026485,
#   'list_pos': 15,
#   'open': True,
#   'id': 412566,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 269,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 466,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 0},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142516509721_269e2943f6360fc91ebf89a61d6377b7_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4858976854135,
#   'end': '00:30:00',
#   'discount_until': None,
#   'categories': ['야식', '테이크아웃', '프랜차이즈', '분식'],
#   'review_avg': 4.7,
#   'min_order_amount': 17000,
#   'distance': 0.7620107606000001,
#   'franchise_name': '(주)놀부 / 돈까스퐁당떡볶이',
#   'except_cash': False,
#   'name': '돈까스퐁당떡볶이공수간-방배점',
#   'phone': '050718666858',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 269,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/돈까스퐁당떡볶이공수간_20180605_Franchise이미지약정서_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 866-10 방배 마에스트로 1동 지층 B103호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 30000,
#   'section_pos': 15,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.1200976,
#   'app_order': True,
#   'lng': 126.991831750109,
#   'list_pos': 16,
#   'open': True,
#   'id': 580805,
#   'estimated_delivery_time': '50~60분',
#   'review_count': 74,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 1088,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201027111706796895_e389fc3cde5601d8d4d3cfc0e05172a8_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '07:30:00',
#   'is_available_pickup': True,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4826184509201,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['한식', '프랜차이즈', '테이크아웃'],
#   'review_avg': 5.0,
#   'min_order_amount': 15000,
#   'distance': 0.10190949131,
#   'franchise_name': '족보잇는국밥 / 족보잇는국밥',
#   'except_cash': False,
#   'name': '족보잇는국밥&밀면-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료~2,000원'},
#   'logo_url': '/media/franchise_logos/족보잇는국밥_20201027_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 977-19 지호2빌딩 1층 104호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 16,
#   'adjusted_delivery_fee': 6400,
#   'is_available_delivery': True,
#   'new_rating': 0.1010464,
#   'app_order': True,
#   'lng': 127.022784829831,
#   'list_pos': 17,
#   'open': True,
#   'id': 447978,
#   'estimated_delivery_time': '29분',
#   'review_count': 609,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 606,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500},
#    'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 5000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210305104101104679_1898275811e801451c972481bfbd8b45_tn.jpg',
#   'reachable': True,
#   'additional_discount': 5000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '09:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO', 'relayo'],
#   'representative_menus': '',
#   'lat': 37.5090438700747,
#   'end': '23:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '카페디저트'],
#   'review_avg': 4.9,
#   'min_order_amount': 14000,
#   'distance': 3.93107998696,
#   'franchise_name': '씨제이푸드빌(주) / 뚜레쥬르',
#   'except_cash': True,
#   'name': '뚜레쥬르-카페강남대로점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 65,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '5,900원', 'basic': '6,400원'},
#   'logo_url': '/media/franchise_logos/뚜레쥬르_20201224_Franchise_crop_200x200.jpg',
#   'address': '서울 강남구 논현동 143-15 건일빌딩 지상1층 102, 103, 104호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 17,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.0749984,
#   'app_order': True,
#   'lng': 126.993691269825,
#   'list_pos': 18,
#   'open': True,
#   'id': 347986,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 1,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'grocery',
#   'franchise_id': 682,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 20000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20190724190643197177_bf9703916c8d6d472b0f5460c3285315_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4836753900094,
#   'end': '00:20:00',
#   'discount_until': None,
#   'categories': ['카페디저트', '편의점', '프랜차이즈'],
#   'review_avg': 5.0,
#   'min_order_amount': 10000,
#   'distance': 0.15546198832,
#   'franchise_name': '(주)비지에프리테일 / CU',
#   'except_cash': True,
#   'name': 'CU-방배원점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/CU_20190322_Franchise이미지약정서_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 928-30 1층 102호'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 18,
#   'adjusted_delivery_fee': 3500,
#   'is_available_delivery': True,
#   'new_rating': 0.0733577,
#   'app_order': True,
#   'lng': 126.981016514431,
#   'list_pos': 19,
#   'open': True,
#   'id': 480587,
#   'estimated_delivery_time': '48~58분',
#   'review_count': 109,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 11,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 0}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210708151455503770_7af4f397aee2f1cd161287c8a2e9503a_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4874564443125,
#   'end': '21:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '테이크아웃', '치킨', '버거'],
#   'review_avg': 4.7,
#   'min_order_amount': 12000,
#   'distance': 1.05795957855,
#   'franchise_name': '주식회사맘스터치앤컴퍼니 / 맘스터치',
#   'except_cash': False,
#   'name': '맘스터치-이수점',
#   'phone': '050352914628',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 81,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,500원'},
#   'logo_url': '/media/franchise_logos/맘스터치_20201116_Franchise_crop_200x200.jpg',
#   'address': '서울 동작구 사당동 139-21 서범빌딩 2층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 19,
#   'adjusted_delivery_fee': 4000,
#   'is_available_delivery': True,
#   'new_rating': 0.0723532,
#   'app_order': True,
#   'lng': 127.017751585306,
#   'list_pos': 20,
#   'open': True,
#   'id': 528245,
#   'estimated_delivery_time': '59~69분',
#   'review_count': 114,
#   'discount_from': '2021-11-12T10:00:00',
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 1200,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 14000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 14000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210113183058604180_b0d241df252d57d98e2349164f936480_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.5153529257566,
#   'end': '23:00:00',
#   'discount_until': '2021-11-12T22:59:59.999999',
#   'categories': ['테이크아웃', '한식', '프랜차이즈', '분식'],
#   'review_avg': 4.3,
#   'min_order_amount': 12000,
#   'distance': 4.20784353862,
#   'franchise_name': '주식회사기영에프앤비 / 떡볶이참잘하는집',
#   'except_cash': False,
#   'name': '떡참떡볶이참잘하는집-신사점',
#   'phone': '050352965341',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 5,
#   'delivery_fee_to_display': {'basic': '4,000원'},
#   'logo_url': '/media/franchise_logos/떡볶이참잘하는집_20210511_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 잠원동 19-5 영서빌딩 19-5 영서빌딩 1층 102-1호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 20,
#   'adjusted_delivery_fee': 4000,
#   'is_available_delivery': True,
#   'new_rating': 0.0722909,
#   'app_order': True,
#   'lng': 126.980670800628,
#   'list_pos': 21,
#   'open': True,
#   'id': 276150,
#   'estimated_delivery_time': '65~75분',
#   'review_count': 171,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 482,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 12000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 4000,
#      'discount_mov': 10000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20201125155657338485_55cbe86cc9acdc021dcc4eebf1ef4fdd_tn.jpg',
#   'reachable': True,
#   'additional_discount': 4000,
#   'new': False,
#   'minimum_pickup_minutes': 30,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4877135667658,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['카페디저트', '테이크아웃', '프랜차이즈', '샌드위치'],
#   'review_avg': 4.6,
#   'min_order_amount': 12000,
#   'distance': 1.0976230035399999,
#   'franchise_name': '(주)섹타나인양재지점 / 파스쿠찌',
#   'except_cash': True,
#   'name': '파스쿠찌-이수역점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 170,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '4,000원'},
#   'logo_url': '/media/franchise_logos/파스쿠치_20180419_Franchise이미지약정서_crop_200x200.png',
#   'address': '서울 동작구 사당동 139-36 1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 50000,
#   'section_pos': 21,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.0721318,
#   'app_order': True,
#   'lng': 126.9811218,
#   'list_pos': 22,
#   'open': True,
#   'id': 245184,
#   'estimated_delivery_time': '24~34분',
#   'review_count': 249,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 57,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 0},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': True,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200609142016465916_6b436eb8d8f13966dc17ccaba8707746_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4756087,
#   'end': '21:00:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '테이크아웃', '한식'],
#   'review_avg': 4.6,
#   'min_order_amount': 19000,
#   'distance': 1.2988844799900001,
#   'franchise_name': '(주)놀부 / 놀부부대찌개',
#   'except_cash': True,
#   'name': '놀부부대찌개-사당점',
#   'phone': '050712905313',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 44,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료~3,000원'},
#   'logo_url': '/media/franchise_logos/놀부부대찌개_20200224_Franchise_crop_200x200.jpg',
#   'address': '서울 관악구 남현동 1061-3'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 22,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.060701,
#   'app_order': True,
#   'lng': 126.986717854856,
#   'list_pos': 23,
#   'open': True,
#   'id': 489659,
#   'estimated_delivery_time': '45~55분',
#   'review_count': 0,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'grocery',
#   'franchise_id': 970,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 5000,
#      'discount_mov': 20000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20200318155630676175_026d8e9a3cfb1f08765589cbc5eb77fe_tn.jpg',
#   'reachable': True,
#   'additional_discount': 5000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.483427116581,
#   'end': '00:30:00',
#   'discount_until': None,
#   'categories': ['편의점', '카페디저트', '프랜차이즈'],
#   'review_avg': 0.0,
#   'min_order_amount': 10000,
#   'distance': 0.46082361567999996,
#   'franchise_name': '(주)코리아세븐 / 세븐일레븐',
#   'except_cash': True,
#   'name': '세븐일레븐-방배17호점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/세븐일레븐_20200214_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 방배동 957-3 쌍영빌딩'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 23,
#   'adjusted_delivery_fee': 4500,
#   'is_available_delivery': True,
#   'new_rating': 0.059567,
#   'app_order': True,
#   'lng': 126.978935482903,
#   'list_pos': 24,
#   'open': True,
#   'id': 338975,
#   'estimated_delivery_time': '43~53분',
#   'review_count': 204,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 737,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 8000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 8000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210304145050593054_cadbe91eb266a0edcc9fbbfff3bd4cc2_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '09:00:00',
#   'is_available_pickup': True,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4780858644222,
#   'end': '23:00:00',
#   'discount_until': None,
#   'categories': ['한식', '프랜차이즈', '테이크아웃', '1인분주문', '찜탕'],
#   'review_avg': 4.6,
#   'min_order_amount': 9000,
#   'distance': 1.2973604187,
#   'franchise_name': '주식회사보강엔터프라이즈 / 큰맘할매순대국',
#   'except_cash': False,
#   'name': '큰맘할매순대국-사당점',
#   'phone': '050712994967',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 43,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '4,500원'},
#   'logo_url': '/media/franchise_logos/큰맘할매순대국_20210225_Franchise_crop_200x200.jpg',
#   'address': '서울 동작구 사당동 1038-33 1층'},
#  {'phone_order': True,
#   'free_delivery_threshold': 0,
#   'section_pos': 24,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.0566534,
#   'app_order': True,
#   'lng': 127.028227186052,
#   'list_pos': 25,
#   'open': True,
#   'id': 480267,
#   'estimated_delivery_time': '50~60분',
#   'review_count': 40,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'hotdeal',
#   'restaurant_type': 'food',
#   'franchise_id': 946,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 2000,
#      'discount_mov': 15000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210426163253885793_c6062f66634c78b5a400f57d86b12cd8_tn.jpg',
#   'reachable': True,
#   'additional_discount': 2000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:45:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4991963367523,
#   'end': '15:00:00',
#   'discount_until': None,
#   'categories': ['피자양식', '프랜차이즈', '테이크아웃'],
#   'review_avg': 4.5,
#   'min_order_amount': 14900,
#   'distance': 3.64480799246,
#   'franchise_name': '주식회사고피자 / 고피자',
#   'except_cash': False,
#   'name': '고피자-강남점',
#   'phone': '050352914315',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 38,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/고피자_20210426_Franchise_crop_200x200_FfCNdy9.jpg',
#   'address': '서울 강남구 역삼동 819 지하1층 4호'},
#  {'phone_order': True,
#   'section_pos': 1,
#   'adjusted_delivery_fee': 0,
#   'is_available_delivery': True,
#   'new_rating': 0.5646999,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.986111666233,
#   'list_pos': 26,
#   'open': True,
#   'id': 331884,
#   'estimated_delivery_time': '29~39분',
#   'review_count': 1896,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210419110000000000_e0eb1a89146b627034d7c9489b5d7d7a_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '09:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4952843427448,
#   'end': '20:50:00',
#   'discount_until': None,
#   'categories': ['중식'],
#   'review_avg': 4.5,
#   'min_order_amount': 10000,
#   'distance': 1.4044038211899998,
#   'minimum_pickup_minutes': 0,
#   'except_cash': False,
#   'name': '동원-방배점',
#   'phone': '050712988101',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1647,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료'},
#   'logo_url': '/media/restaurant_logos/스탁_20210623_DHK내부_짜장면_Side01_300x300_RVDI84_VKaprBf.jpg',
#   'address': '서울 서초구 방배동 769-1 2층'},
#  {'phone_order': False,
#   'section_pos': 2,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.5187458,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.983402953314,
#   'list_pos': 27,
#   'open': True,
#   'id': 574509,
#   'estimated_delivery_time': '21분',
#   'review_count': 177,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 2900, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210720103514843292_3f0009cc923fdb0476bc4eeddcd0f492_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4874676953048,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['고기구이', '프랜차이즈', '1인분주문', '한식'],
#   'review_avg': 4.6,
#   'min_order_amount': 8900,
#   'distance': 0.8711246434800001,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '덮다-방배점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 177,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '무료', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20210720_574509_덮다-방배점_대표사진_300x300.jpg',
#   'address': '서울 서초구 방배동 1458 2층'},
#  {'phone_order': True,
#   'section_pos': 3,
#   'adjusted_delivery_fee': 0,
#   'is_available_delivery': True,
#   'new_rating': 0.5142113,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 127.015078736975,
#   'list_pos': 28,
#   'open': True,
#   'id': 458367,
#   'estimated_delivery_time': '41~51분',
#   'review_count': 1422,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210419110000000000_32912f1c0a8a1ff06a4cf1d9091f3c0a_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:30:00',
#   'is_available_pickup': True,
#   'tags': ['excellent'],
#   'representative_menus': '',
#   'lat': 37.4883093685504,
#   'end': '21:00:00',
#   'discount_until': None,
#   'categories': ['중식', '1인분주문', '아시안', '테이크아웃'],
#   'review_avg': 4.9,
#   'min_order_amount': 6000,
#   'distance': 2.10972309399,
#   'minimum_pickup_minutes': 20,
#   'except_cash': False,
#   'name': '취홍-서울교대점',
#   'phone': '050352881878',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 4,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료'},
#   'logo_url': '/media/restaurant_logos/스탁_20190917_DHK촬영합성_간짜장-차돌박이짬뽕-탕수육_Top01_300x300_OZBTUwf.jpg',
#   'address': '서울 서초구 서초동 1624-2 서초제일빌딩 지하1층'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 4,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': -0.3642283,
#   'app_order': True,
#   'lng': 126.982851850389,
#   'list_pos': 29,
#   'open': True,
#   'id': 1031154,
#   'estimated_delivery_time': '20분',
#   'review_count': 0,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 0, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20211109154842033028_113927c5a903a61dc5caf788901ab0ac_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': True,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '09:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4784687157631,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['한식', '찜탕'],
#   'review_avg': 0.0,
#   'min_order_amount': 18000,
#   'distance': 0.9796865449,
#   'minimum_pickup_minutes': 1,
#   'except_cash': True,
#   'name': '초동집',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/스탁_20190809_DHK촬영_갈비탕_Top01_300x300_gNvShOv.jpg',
#   'address': '서울특별시 서초구 방배동 452-4 1층'},
#  {'phone_order': False,
#   'section_pos': 5,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.0944265,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.996717592567,
#   'list_pos': 30,
#   'open': True,
#   'id': 435538,
#   'estimated_delivery_time': '44~54분',
#   'review_count': 58,
#   'discount_from': '2021-11-12T09:00:00',
#   'is_deliverable': True,
#   'section': 'contract',
# ...
#   'categories': ['테이크아웃', '프랜차이즈', '카페디저트'],
#   'review_avg': 4.8,
#   'min_order_amount': 12000,
#   'distance': 1.0708318989199999,
#   'franchise_name': '(주)섹타나인양재지점 / 파리바게뜨',
#   'except_cash': True,
#   'name': '파리바게뜨-사당파스텔시티점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 786,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/파리바게뜨_20180712_Franchise이미지약정서_crop_200x200_s6Zm07l.jpg',
#   'address': '서울 서초구 방배동 444-3 SK리더스뷰 101호 일부'},
#  {'phone_order': False,
#   'section_pos': 26,
#   'adjusted_delivery_fee': 3400,
#   'is_available_delivery': True,
#   'new_rating': 0.3874802,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.973214881183,
#   'list_pos': 51,
#   'open': True,
#   'id': 532071,
#   'estimated_delivery_time': '24분',
#   'review_count': 56,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 1000, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210115181657466161_efadff88b2fcda2bd01c3f98b1cad0dc_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4762561328101,
#   'end': '12:00:00',
#   'discount_until': None,
#   'categories': ['카페디저트'],
#   'review_avg': 5.0,
#   'min_order_amount': 8400,
#   'distance': 1.83961276254,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '라자루스카페',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 4,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '1,900원', 'basic': '3,400원'},
#   'logo_url': '/media/restaurant_logos/스탁_20190801_DHK촬영_아메리카노HOT_Side01_300x300_DMQEuH7.jpg',
#   'address': '서울 동작구 사당동 1049-7 중앙대학교동창회관 1층 2호'},
#  {'phone_order': True,
#   'section_pos': 27,
#   'adjusted_delivery_fee': 3000,
#   'is_available_delivery': True,
#   'new_rating': 0.3849381,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.983083724903,
#   'list_pos': 52,
#   'open': True,
#   'id': 410782,
#   'estimated_delivery_time': '52~62분',
#   'review_count': 1684,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 37,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20191014171511754363_c7be81a92573dbcea9bc5988012d0051_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': '(주)비에이치씨 / BHC치킨',
#   'thumbnail_message': '',
#   'begin': '09:00:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO', 'relayo'],
#   'representative_menus': '',
#   'lat': 37.4860317859567,
#   'end': '23:50:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '테이크아웃', '치킨'],
#   'review_avg': 4.8,
#   'min_order_amount': 15000,
#   'distance': 0.82933680184,
#   'minimum_pickup_minutes': 20,
#   'except_cash': False,
#   'name': 'BHC-이수점',
#   'phone': '050718667052',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1183,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '3,000원'},
#   'logo_url': '/media/franchise_logos/BHC_20210329_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 3001-2 방배디오슈페리움1 3001-2 방배디오슈페리움1 104, 104-1호'},
#  {'phone_order': True,
#   'section_pos': 28,
#   'adjusted_delivery_fee': 2800,
#   'is_available_delivery': True,
#   'new_rating': 0.3806494,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 127.013923901648,
#   'list_pos': 53,
#   'open': True,
#   'id': 354615,
#   'estimated_delivery_time': '60~70분',
#   'review_count': 1537,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 1366,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210614104231543480_14b8dfa7b30e20334dcb46b062104dee_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': '(주)씨디씨 / 마라하오',
#   'thumbnail_message': '',
#   'begin': '10:30:00',
#   'is_available_pickup': True,
#   'tags': ['CESCO'],
#   'representative_menus': '',
#   'lat': 37.4965683030573,
#   'end': '02:00:00',
#   'discount_until': None,
#   'categories': ['아시안', '프랜차이즈', '중식', '테이크아웃', '야식', '찜탕'],
#   'review_avg': 4.7,
#   'min_order_amount': 12900,
#   'distance': 2.4215875426399998,
#   'minimum_pickup_minutes': 20,
#   'except_cash': False,
#   'name': '마라하오-서초점',
#   'phone': '050718609871',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 1185,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,800원'},
#   'logo_url': '/media/franchise_logos/마라하오_20210614_Franchise_crop_200x200.jpg',
#   'address': '서울 서초구 서초동 1698-3 청석빌딩 지하1층'},
#  {'phone_order': True,
#   'section_pos': 29,
#   'adjusted_delivery_fee': 1000,
#   'is_available_delivery': True,
#   'new_rating': 0.3783313,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.982612958792,
#   'list_pos': 54,
#   'open': True,
#   'id': 286881,
#   'estimated_delivery_time': '40~50분',
#   'review_count': 1106,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 712,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20211108122607571169_9bd3bf281ba610597e7b22ce01db2fd9_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'thumbnail_message': '',
#   'begin': '10:40:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'address': '서울 서초구 방배동 3001-1 디오슈페리움2 102호',
#   'lat': 37.4860432880112,
#   'end': '21:30:00',
#   'discount_until': None,
#   'categories': ['프랜차이즈', '분식', '아시안', '한식'],
#   'review_avg': 4.7,
#   'min_order_amount': 12000,
#   'distance': 0.86899219502,
#   'franchise_name': '(주)엠푸드에스엔시 / 미스사이공',
#   'except_cash': False,
#   'name': '베트남쌀국수미스사이공-이수점',
#   'phone': '050712945444',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 123,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '1,000원'},
#   'logo_url': '/media/franchise_logos/미스사이공_20190517_Franchise_crop_200x200.jpg'},
#  {'phone_order': False,
#   'section_pos': 30,
#   'adjusted_delivery_fee': 2900,
#   'is_available_delivery': True,
#   'new_rating': 0.3759198,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.988846353989,
#   'list_pos': 55,
#   'open': True,
#   'id': 571296,
#   'estimated_delivery_time': '21분',
#   'review_count': 0,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 500, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210614130000000000_0a49177ac7d48b117288b184f024ea37_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '09:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.495779703385,
#   'end': '21:00:00',
#   'discount_until': None,
#   'categories': ['카페디저트'],
#   'review_avg': 0.0,
#   'min_order_amount': 12000,
#   'distance': 1.38905613158,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '해피커피',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '1,900원', 'basic': '2,900원'},
#   'logo_url': '/media/restaurant_logos/스탁_20190801_DHK촬영_그린티라떼HOT-아메리카노ICE-에스프레소_Top02_300x300_9dFS5d3.jpg',
#   'address': '서울 서초구 방배동 19-3 1층 107호'},
#  {'phone_order': False,
#   'free_delivery_threshold': 0,
#   'section_pos': 31,
#   'adjusted_delivery_fee': 3900,
#   'is_available_delivery': True,
#   'new_rating': -0.4000612,
#   'app_order': True,
#   'lng': 127.013418784531,
#   'list_pos': 56,
#   'open': True,
#   'id': 1028988,
#   'estimated_delivery_time': '23분',
#   'review_count': 2,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 1000, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20211110101832765389_8ee61acb7247dd2bb374589921bc1e67_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': True,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4930094310671,
#   'end': '21:00:00',
#   'discount_until': None,
#   'categories': ['한식', '도시락죽', '찜탕'],
#   'review_avg': 5.0,
#   'min_order_amount': 15000,
#   'distance': 2.1685456834699997,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '립이야등갈비',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 2,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '2,400원', 'basic': '3,900원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20211110_1028988_립이야등갈비_대표사진_300x300.jpg',
#   'address': '서울특별시 서초구 서초동 1573-10 로이어즈타워 지하1층 B18호'},
#  {'phone_order': True,
#   'section_pos': 32,
#   'adjusted_delivery_fee': 4000,
#   'is_available_delivery': True,
#   'new_rating': 0.3685157,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 127.026121185242,
#   'list_pos': 57,
#   'open': True,
#   'id': 413273,
#   'estimated_delivery_time': '46~56분',
#   'review_count': 13505,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20210716174409966897_fef4e82b00807e2c7b85790e038c3d2e_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': False,
#   'tags': ['CESCO', 'excellent'],
#   'representative_menus': '',
#   'lat': 37.5072362315182,
#   'end': '09:59:00',
#   'discount_until': None,
#   'categories': ['족발보쌈'],
#   'review_avg': 4.8,
#   'min_order_amount': 11000,
#   'distance': 4.00526619076,
#   'minimum_pickup_minutes': 0,
#   'except_cash': False,
#   'name': '기대만족-본점',
#   'phone': '050718667411',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 13485,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '4,000원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20200116_413273_기대만족-강남본점_대표사진_300x300_JyNNjjj.jpg',
#   'address': '서울 강남구 논현동 181-14 지하1층'},
#  {'phone_order': True,
#   'section_pos': 33,
#   'adjusted_delivery_fee': 1900,
#   'is_available_delivery': True,
#   'new_rating': 0.3638203,
#   'app_order': True,
#   'free_delivery_threshold': 45000,
#   'lng': 126.994658186875,
#   'list_pos': 58,
#   'open': True,
#   'id': 502995,
#   'estimated_delivery_time': '37~47분',
#   'review_count': 896,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 379,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 6000,
#      'discount_mov': 18800},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 6000,
#      'discount_mov': 18800}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20210907135553365328_005b0b30e6d7cf00336014679aea181c_tn.jpg',
#   'reachable': True,
#   'additional_discount': 6000,
#   'new': False,
#   'minimum_pickup_minutes': 20,
#   'thumbnail_message': '',
#   'begin': '10:00:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4826159849125,
#   'end': '02:00:00',
#   'discount_until': None,
#   'categories': ['한식', '찜탕', '테이크아웃', '프랜차이즈'],
#   'review_avg': 4.9,
#   'min_order_amount': 16000,
#   'distance': 0.26062970442,
#   'franchise_name': '주식회사기영에프앤비 / 두찜',
#   'except_cash': False,
#   'name': '두마리찜닭두찜-서초방배점',
#   'phone': '050352938520',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 786,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '무료~1,900원'},
#   'logo_url': '/media/franchise_logos/두찜_20191219_Franchise_crop_200x200.jpg',
#   'address': '서울특별시 서초구 방배동 922-24 922-24 1층'},
#  {'phone_order': False,
#   'section_pos': 34,
#   'adjusted_delivery_fee': 2000,
#   'is_available_delivery': True,
#   'new_rating': 0.3591383,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 126.9813316,
#   'list_pos': 59,
#   'open': True,
#   'id': 289550,
#   'estimated_delivery_time': '55~65분',
#   'review_count': 1064,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': 475,
#   'discounts': {'additional': {'delivery': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 12000},
#     'pickup': {'only_for_member': True,
#      'is_per_menu': False,
#      'amount': 3000,
#      'discount_mov': 12000}}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/franchise/thumbnail/20191224184656261511_b805645605e9421d51b14065d899f0e4_tn.jpg',
#   'reachable': True,
#   'additional_discount': 3000,
#   'new': False,
#   'minimum_pickup_minutes': 10,
#   'thumbnail_message': '',
#   'begin': '10:20:00',
#   'is_available_pickup': True,
#   'tags': ['relayo'],
#   'representative_menus': '',
#   'lat': 37.4787069999301,
#   'end': '22:00:00',
#   'discount_until': None,
#   'categories': ['테이크아웃', '카페디저트', '프랜차이즈'],
#   'review_avg': 4.9,
#   'min_order_amount': 12000,
#   'distance': 1.07878402744,
#   'franchise_name': '(주)섹타나인양재지점 / 파리바게뜨',
#   'except_cash': True,
#   'name': '파리바게뜨-사당역점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['online'],
#   'delivery_method': 'VD',
#   'owner_reply_count': 385,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'basic': '2,000원'},
#   'logo_url': '/media/franchise_logos/파리바게뜨_20180712_Franchise이미지약정서_crop_200x200_s6Zm07l.jpg',
#   'address': '서울 동작구 사당동 1031-28'},
#  {'phone_order': False,
#   'section_pos': 35,
#   'adjusted_delivery_fee': 3400,
#   'is_available_delivery': True,
#   'new_rating': 0.3489582,
#   'app_order': True,
#   'free_delivery_threshold': 0,
#   'lng': 127.009615169499,
#   'list_pos': 60,
#   'open': True,
#   'id': 332627,
#   'estimated_delivery_time': '20분',
#   'review_count': 126,
#   'discount_from': None,
#   'is_deliverable': True,
#   'section': 'contract',
#   'restaurant_type': 'food',
#   'franchise_id': None,
#   'discounts': {'delivery_fee': {'funding': 3400, 'campaign': 500}},
#   'thumbnail_url': 'https://rev-static.yogiyo.co.kr/restaurants/thumbnail/20211018130000000000_670327a7db4d8ff832d927528ce14e84_tn.jpg',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'franchise_name': None,
#   'thumbnail_message': '',
#   'begin': '10:15:00',
#   'is_available_pickup': False,
#   'tags': [],
#   'representative_menus': '',
#   'lat': 37.4893743651715,
#   'end': '22:35:00',
#   'discount_until': None,
#   'categories': ['피자양식'],
#   'review_avg': 4.8,
#   'min_order_amount': 14000,
#   'distance': 1.68957117763,
#   'minimum_pickup_minutes': 0,
#   'except_cash': True,
#   'name': '펠리스산쵸-서초점',
#   'phone': '0000000000',
#   'reason': None,
#   'payment_methods': ['creditcard', 'online'],
#   'delivery_method': 'OD',
#   'owner_reply_count': 0,
#   'discount_percent': 0,
#   'delivery_fee_to_display': {'discounted': '무료', 'basic': '3,400원'},
#   'logo_url': '/media/restaurant_logos/업체자체_20210329_332627_펠리스산쵸-서초점_대표사진_300x300.jpg',
#   'address': '서울 서초구 서초동 1544-9 세바빌딩 1층 1호'}]

# %%
# list comprehension

# 담기로 한 정보 : 매장명, 평점평균, 리뷰수, 사장님답글수, 할인정보, 배달료정보, 최소주문금액

result = [
    {
        "매장명":el.get('name').strip(),
        "평점평균":el.get('review_avg'),
        "리뷰수":el.get('review_count'),
        "사장님답글수":el.get('owner_reply_count'),
        "최소주문금액":el.get('min_order_amount'),
    }
    for el in ygy_data['restaurants']
]

result
# Out:
# [{'매장명': '김가네-방배본동점', '평점평균': 4.6, '리뷰수': 1375, '사장님답글수': 51, '최소주문금액': 15000},
#  {'매장명': '두마리찜닭두찜-서초방배점',
#   '평점평균': 4.9,
#   '리뷰수': 896,
#   '사장님답글수': 786,
#   '최소주문금액': 16000},
#  {'매장명': '놀부보쌈족발-서초점',
#   '평점평균': 4.6,
#   '리뷰수': 711,
#   '사장님답글수': 693,
#   '최소주문금액': 12000},
#  {'매장명': '컬투치킨-서초1호점',
#   '평점평균': 4.8,
#   '리뷰수': 1172,
#   '사장님답글수': 1020,
#   '최소주문금액': 16000},
#  {'매장명': '쫄면주는삼겹본능by놀부-방배점',
#   '평점평균': 4.8,
#   '리뷰수': 969,
#   '사장님답글수': 959,
#   '최소주문금액': 17000},
#  {'매장명': '파리바게뜨-방배점', '평점평균': 4.7, '리뷰수': 386, '사장님답글수': 67, '최소주문금액': 12000},
#  {'매장명': '버거킹-방배점', '평점평균': 4.7, '리뷰수': 445, '사장님답글수': 203, '최소주문금액': 8000},
#  {'매장명': '에그드랍-방배점', '평점평균': 4.5, '리뷰수': 130, '사장님답글수': 0, '최소주문금액': 8000},
#  {'매장명': '투썸플레이스-방배역점', '평점평균': 4.5, '리뷰수': 99, '사장님답글수': 83, '최소주문금액': 12000},
#  {'매장명': 'PB델리-방배현대점', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 11000},
#  {'매장명': '흥부찜닭by놀부-방배점',
#   '평점평균': 4.9,
#   '리뷰수': 495,
#   '사장님답글수': 493,
#   '최소주문금액': 15000},
#  {'매장명': '파리크라상-반포서래점',
#   '평점평균': 4.7,
#   '리뷰수': 139,
#   '사장님답글수': 128,
#   '최소주문금액': 15000},
#  {'매장명': '배스킨라빈스-사당방배점',
#   '평점평균': 4.7,
#   '리뷰수': 426,
#   '사장님답글수': 0,
#   '최소주문금액': 13500},
#  {'매장명': '빕스얌딜리버리-서초점',
#   '평점평균': 4.8,
#   '리뷰수': 306,
#   '사장님답글수': 305,
#   '최소주문금액': 20000},
#  {'매장명': '돈까스퐁당떡볶이공수간-방배점',
#   '평점평균': 4.7,
#   '리뷰수': 269,
#   '사장님답글수': 269,
#   '최소주문금액': 17000},
#  {'매장명': '족보잇는국밥&밀면-방배점',
#   '평점평균': 5.0,
#   '리뷰수': 74,
#   '사장님답글수': 0,
#   '최소주문금액': 15000},
#  {'매장명': '뚜레쥬르-카페강남대로점',
#   '평점평균': 4.9,
#   '리뷰수': 609,
#   '사장님답글수': 65,
#   '최소주문금액': 14000},
#  {'매장명': 'CU-방배원점', '평점평균': 5.0, '리뷰수': 1, '사장님답글수': 0, '최소주문금액': 10000},
#  {'매장명': '맘스터치-이수점', '평점평균': 4.7, '리뷰수': 109, '사장님답글수': 81, '최소주문금액': 12000},
#  {'매장명': '떡참떡볶이참잘하는집-신사점',
#   '평점평균': 4.3,
#   '리뷰수': 114,
#   '사장님답글수': 0,
#   '최소주문금액': 12000},
#  {'매장명': '파스쿠찌-이수역점', '평점평균': 4.6, '리뷰수': 171, '사장님답글수': 170, '최소주문금액': 12000},
#  {'매장명': '놀부부대찌개-사당점', '평점평균': 4.6, '리뷰수': 249, '사장님답글수': 44, '최소주문금액': 19000},
#  {'매장명': '세븐일레븐-방배17호점', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 10000},
#  {'매장명': '큰맘할매순대국-사당점', '평점평균': 4.6, '리뷰수': 204, '사장님답글수': 43, '최소주문금액': 9000},
#  {'매장명': '고피자-강남점', '평점평균': 4.5, '리뷰수': 40, '사장님답글수': 38, '최소주문금액': 14900},
#  {'매장명': '동원-방배점', '평점평균': 4.5, '리뷰수': 1896, '사장님답글수': 1647, '최소주문금액': 10000},
#  {'매장명': '덮다-방배점', '평점평균': 4.6, '리뷰수': 177, '사장님답글수': 177, '최소주문금액': 8900},
#  {'매장명': '취홍-서울교대점', '평점평균': 4.9, '리뷰수': 1422, '사장님답글수': 4, '최소주문금액': 6000},
#  {'매장명': '초동집', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 18000},
#  {'매장명': '혼밥대왕-서초점', '평점평균': 4.4, '리뷰수': 58, '사장님답글수': 49, '최소주문금액': 7900},
#  {'매장명': '스쿨푸드-방배점',
#   '평점평균': 4.7,
#   '리뷰수': 2254,
#   '사장님답글수': 2251,
#   '최소주문금액': 12000},
#  {'매장명': '조이플', '평점평균': 4.9, '리뷰수': 1531, '사장님답글수': 61, '최소주문금액': 8000},
#  {'매장명': '가츠몽-서초점', '평점평균': 4.6, '리뷰수': 93, '사장님답글수': 68, '최소주문금액': 13000},
#  {'매장명': '커피앤티몽', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 12000},
#  {'매장명': '밥도둑한끼뚝딱-서초점', '평점평균': 4.2, '리뷰수': 35, '사장님답글수': 26, '최소주문금액': 7900},
#  {'매장명': '노량진수산시장벌교아줌마',
#   '평점평균': 4.7,
#   '리뷰수': 768,
#   '사장님답글수': 743,
#   '최소주문금액': 13000},
#  {'매장명': '명인만두-내방역점', '평점평균': 4.7, '리뷰수': 1627, '사장님답글수': 1, '최소주문금액': 10000},
#  {'매장명': '맥도날드-방배점', '평점평균': 4.6, '리뷰수': 2052, '사장님답글수': 0, '최소주문금액': 3000},
#  {'매장명': '띵떡-서초점', '평점평균': 4.3, '리뷰수': 16, '사장님답글수': 10, '최소주문금액': 9000},
#  {'매장명': '만다린-방배점', '평점평균': 4.6, '리뷰수': 1468, '사장님답글수': 0, '최소주문금액': 11000},
#  {'매장명': 'BHC-사당점', '평점평균': 4.6, '리뷰수': 3116, '사장님답글수': 2510, '최소주문금액': 15000},
#  {'매장명': '맛카오치킨', '평점평균': 4.8, '리뷰수': 1361, '사장님답글수': 1106, '최소주문금액': 10800},
#  {'매장명': '어흥분식-강남본점', '평점평균': 4.8, '리뷰수': 14, '사장님답글수': 0, '최소주문금액': 15000},
#  {'매장명': '파리바게뜨-이수태평점',
#   '평점평균': 4.8,
#   '리뷰수': 1660,
#   '사장님답글수': 1407,
#   '최소주문금액': 12000},
#  {'매장명': '이수카페사이', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 10500},
#  {'매장명': '샌드위치카페하이나', '평점평균': 5.0, '리뷰수': 917, '사장님답글수': 915, '최소주문금액': 13000},
#  {'매장명': '샐러디-서초역점', '평점평균': 5.0, '리뷰수': 4, '사장님답글수': 2, '최소주문금액': 10000},
#  {'매장명': '차고집냉면&돈까스-서초사당점',
#   '평점평균': 5.0,
#   '리뷰수': 1025,
#   '사장님답글수': 1024,
#   '최소주문금액': 12000},
#  {'매장명': '타이반쩜-교대점', '평점평균': 4.7, '리뷰수': 2571, '사장님답글수': 2551, '최소주문금액': 5000},
#  {'매장명': '파리바게뜨-사당파스텔시티점',
#   '평점평균': 4.8,
#   '리뷰수': 1435,
#   '사장님답글수': 786,
#   '최소주문금액': 12000},
#  {'매장명': '라자루스카페', '평점평균': 5.0, '리뷰수': 56, '사장님답글수': 4, '최소주문금액': 8400},
#  {'매장명': 'BHC-이수점', '평점평균': 4.8, '리뷰수': 1684, '사장님답글수': 1183, '최소주문금액': 15000},
#  {'매장명': '마라하오-서초점',
#   '평점평균': 4.7,
#   '리뷰수': 1537,
#   '사장님답글수': 1185,
#   '최소주문금액': 12900},
#  {'매장명': '베트남쌀국수미스사이공-이수점',
#   '평점평균': 4.7,
#   '리뷰수': 1106,
#   '사장님답글수': 123,
#   '최소주문금액': 12000},
#  {'매장명': '해피커피', '평점평균': 0.0, '리뷰수': 0, '사장님답글수': 0, '최소주문금액': 12000},
#  {'매장명': '립이야등갈비', '평점평균': 5.0, '리뷰수': 2, '사장님답글수': 2, '최소주문금액': 15000},
#  {'매장명': '기대만족-본점',
#   '평점평균': 4.8,
#   '리뷰수': 13505,
#   '사장님답글수': 13485,
#   '최소주문금액': 11000},
#  {'매장명': '두마리찜닭두찜-서초방배점',
#   '평점평균': 4.9,
#   '리뷰수': 896,
#   '사장님답글수': 786,
#   '최소주문금액': 16000},
#  {'매장명': '파리바게뜨-사당역점',
#   '평점평균': 4.9,
#   '리뷰수': 1064,
#   '사장님답글수': 385,
#   '최소주문금액': 12000},
#  {'매장명': '펠리스산쵸-서초점', '평점평균': 4.8, '리뷰수': 126, '사장님답글수': 0, '최소주문금액': 14000}]

# %%
df = pd.DataFrame(result)
df.head(10)  # 인덱스 순서 상위10개
# Out:
#                 매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 0         김가네-방배본동점   4.6  1375      51   15000
# 1     두마리찜닭두찜-서초방배점   4.9   896     786   16000
# 2        놀부보쌈족발-서초점   4.6   711     693   12000
# 3        컬투치킨-서초1호점   4.8  1172    1020   16000
# 4  쫄면주는삼겹본능by놀부-방배점   4.8   969     959   17000
# 5         파리바게뜨-방배점   4.7   386      67   12000
# 6           버거킹-방배점   4.7   445     203    8000
# 7          에그드랍-방배점   4.5   130       0    8000
# 8       투썸플레이스-방배역점   4.5    99      83   12000
# 9        PB델리-방배현대점   0.0     0       0   11000

# %%
# 리뷰수 기준 상위 20개 가게
df.sort_values('리뷰수', ascending=False)[:20]
# Out:
#                 매장명  평점평균    리뷰수  사장님답글수  최소주문금액
# 56          기대만족-본점   4.8  13505   13485   11000
# 40          BHC-사당점   4.6   3116    2510   15000
# 48         타이반쩜-교대점   4.7   2571    2551    5000
# 30         스쿨푸드-방배점   4.7   2254    2251   12000
# 37         맥도날드-방배점   4.6   2052       0    3000
# 25           동원-방배점   4.5   1896    1647   10000
# 51          BHC-이수점   4.8   1684    1183   15000
# 43      파리바게뜨-이수태평점   4.8   1660    1407   12000
# 36        명인만두-내방역점   4.7   1627       1   10000
# 52         마라하오-서초점   4.7   1537    1185   12900
# 31              조이플   4.9   1531      61    8000
# 39          만다린-방배점   4.6   1468       0   11000
# 49   파리바게뜨-사당파스텔시티점   4.8   1435     786   12000
# 27         취홍-서울교대점   4.9   1422       4    6000
# 0         김가네-방배본동점   4.6   1375      51   15000
# 41            맛카오치킨   4.8   1361    1106   10800
# 3        컬투치킨-서초1호점   4.8   1172    1020   16000
# 53  베트남쌀국수미스사이공-이수점   4.7   1106     123   12000
# 58       파리바게뜨-사당역점   4.9   1064     385   12000
# 47  차고집냉면&돈까스-서초사당점   5.0   1025    1024   12000

# %%
# 평점평균 기준 상위 20개 가게
df.sort_values('평점평균', ascending=False)[:20]
# Out:
#                 매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 15    족보잇는국밥&밀면-방배점   5.0    74       0   15000
# 47  차고집냉면&돈까스-서초사당점   5.0  1025    1024   12000
# 50           라자루스카페   5.0    56       4    8400
# 46         샐러디-서초역점   5.0     4       2   10000
# 55           립이야등갈비   5.0     2       2   15000
# 17          CU-방배원점   5.0     1       0   10000
# 45        샌드위치카페하이나   5.0   917     915   13000
# 31              조이플   4.9  1531      61    8000
# 10     흥부찜닭by놀부-방배점   4.9   495     493   15000
# 1     두마리찜닭두찜-서초방배점   4.9   896     786   16000
# 16     뚜레쥬르-카페강남대로점   4.9   609      65   14000
# 57    두마리찜닭두찜-서초방배점   4.9   896     786   16000
# 27         취홍-서울교대점   4.9  1422       4    6000
# 58       파리바게뜨-사당역점   4.9  1064     385   12000
# 42        어흥분식-강남본점   4.8    14       0   15000
# 41            맛카오치킨   4.8  1361    1106   10800
# 43      파리바게뜨-이수태평점   4.8  1660    1407   12000
# 59        펠리스산쵸-서초점   4.8   126       0   14000
# 13      빕스얌딜리버리-서초점   4.8   306     305   20000
# 51          BHC-이수점   4.8  1684    1183   15000

# %%
# 근데 평점 평균으로는 리뷰수가 적은 가게도 높게 나오기 때문에 신뢰할만한 표본으로 보기 어렵다
# 뭔가 맛집 반영이 제대로 되지 않는거 같다.
# 최소 리뷰수 300이 넘는 가게만 모아서 따로 순위를 내보자

# %%
review_count_over300 = df[df['리뷰수']>= 300]
review_count_over300[:20]
# Out:
#                  매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 0          김가네-방배본동점   4.6  1375      51   15000
# 1      두마리찜닭두찜-서초방배점   4.9   896     786   16000
# 2         놀부보쌈족발-서초점   4.6   711     693   12000
# 3         컬투치킨-서초1호점   4.8  1172    1020   16000
# 4   쫄면주는삼겹본능by놀부-방배점   4.8   969     959   17000
# 5          파리바게뜨-방배점   4.7   386      67   12000
# 6            버거킹-방배점   4.7   445     203    8000
# 10      흥부찜닭by놀부-방배점   4.9   495     493   15000
# 12      배스킨라빈스-사당방배점   4.7   426       0   13500
# 13       빕스얌딜리버리-서초점   4.8   306     305   20000
# 16      뚜레쥬르-카페강남대로점   4.9   609      65   14000
# 25            동원-방배점   4.5  1896    1647   10000
# 27          취홍-서울교대점   4.9  1422       4    6000
# 30          스쿨푸드-방배점   4.7  2254    2251   12000
# 31               조이플   4.9  1531      61    8000
# 35      노량진수산시장벌교아줌마   4.7   768     743   13000
# 36         명인만두-내방역점   4.7  1627       1   10000
# 37          맥도날드-방배점   4.6  2052       0    3000
# 39           만다린-방배점   4.6  1468       0   11000
# 40           BHC-사당점   4.6  3116    2510   15000

# %%
review_count_over300 = review_count_over300.sort_values('평점평균', ascending=False).reset_index(drop=True)
review_count_over300.index += 1
review_count_over300[:20]
# Out:
#                  매장명  평점평균    리뷰수  사장님답글수  최소주문금액
# 1          샌드위치카페하이나   5.0    917     915   13000
# 2    차고집냉면&돈까스-서초사당점   5.0   1025    1024   12000
# 3         파리바게뜨-사당역점   4.9   1064     385   12000
# 4       흥부찜닭by놀부-방배점   4.9    495     493   15000
# 5      두마리찜닭두찜-서초방배점   4.9    896     786   16000
# 6                조이플   4.9   1531      61    8000
# 7           취홍-서울교대점   4.9   1422       4    6000
# 8       뚜레쥬르-카페강남대로점   4.9    609      65   14000
# 9      두마리찜닭두찜-서초방배점   4.9    896     786   16000
# 10       빕스얌딜리버리-서초점   4.8    306     305   20000
# 11             맛카오치킨   4.8   1361    1106   10800
# 12           BHC-이수점   4.8   1684    1183   15000
# 13    파리바게뜨-사당파스텔시티점   4.8   1435     786   12000
# 14           기대만족-본점   4.8  13505   13485   11000
# 15  쫄면주는삼겹본능by놀부-방배점   4.8    969     959   17000
# 16        컬투치킨-서초1호점   4.8   1172    1020   16000
# 17       파리바게뜨-이수태평점   4.8   1660    1407   12000
# 18          마라하오-서초점   4.7   1537    1185   12900
# 19   베트남쌀국수미스사이공-이수점   4.7   1106     123   12000
# 20          타이반쩜-교대점   4.7   2571    2551    5000

# %%
# 리뷰수 최소 300 이상인 가게 중 평점 높은 가게 top 10
result1 = review_count_over300[:10]
result1
# Out:
#                 매장명  평점평균   리뷰수  사장님답글수  최소주문금액
# 1         샌드위치카페하이나   5.0   917     915   13000
# 2   차고집냉면&돈까스-서초사당점   5.0  1025    1024   12000
# 3        파리바게뜨-사당역점   4.9  1064     385   12000
# 4      흥부찜닭by놀부-방배점   4.9   495     493   15000
# 5     두마리찜닭두찜-서초방배점   4.9   896     786   16000
# 6               조이플   4.9  1531      61    8000
# 7          취홍-서울교대점   4.9  1422       4    6000
# 8      뚜레쥬르-카페강남대로점   4.9   609      65   14000
# 9     두마리찜닭두찜-서초방배점   4.9   896     786   16000
# 10      빕스얌딜리버리-서초점   4.8   306     305   20000
